# %%
import pandas as pd
import numpy as np
from IPython.display import display
from utils import *
from recommender import *
from df_utils import *
import json
from pandas import DataFrame

# %%
create_df_from_2_df_col(json_df_to_pd_df('json_test.txt'),output_file='tag_comp_test_2.csv',col_1='tags', col_2 ='components',row_cut=5,col_cut=20)
# Out:
#                         Arduino MKR WiFi 1010  PCBWay Custom PCB  \
# remote control                              0                  1
# machine learning                            1                  0
# 3d printing                                 1                  3
# robot                                       0                  0
# led                                         0                  7
# arduino                                     0                  1
# rfid                                        0                  0
# remote                                      0                  0
# display                                     0                  3
# home automation                             1                  9
# voice control                               0                  0
# self balancing robot                        0                  0
# audio                                       0                  1
# ...

# %%
create_df_from_2_df_col(json_df_to_pd_df('json_test.txt'),output_file='tag_comp_test_from_jsontest.csv',col_1='tags', col_2 ='components',row_cut=5,col_cut=10)
# Out:
#                       DHT22 Temperature Sensor  \
# remote control                               1
# machine learning                             0
# 3d printing                                  0
# arduino motor driver                         0
# robot                                        0
# ...                                        ...
# security                                     0
# password                                     0
# app                                          0
# smart fan                                    0
# companion                                    0
#
#                       SparkFun Stepper motor driver board A4988  \
# remote control                                                1
# machine learning                                              0
# 3d printing                                                   2
# arduino motor driver                                          0
# robot                                                         2
# ...

# %%
create_df_from_2_df_col(json_df_to_pd_df('all_project_detail_final_201022.txt'),output_file='tag_comp_test_cut_5_20.csv',col_1='tags', col_2 ='components',row_cut=5,col_cut=20)
# Out:
#                         RobotGeek 180 Degree Robot Servo  \
# interactive                                            0
# eeg                                                    0
# single board computer                                  0
# seismometer                                            0
# ds3231 alarm interrupt                                 0
# ...                                                  ...
# mofset                                                 0
# astronomical                                           0
# engraving                                              0
# open source                                            0
# hat                                                    0
#
#                         SparkFun FTDI Basic Breakout - 3.3V  \
# interactive                                               0
# eeg                                                       0
# single board computer                                     0
# ...

# %%
df_to_surprise_df(input_file='tag_comp_test_cut_5_20.csv',output_file='surprise_tag_comp_test_cut_5_20.csv', index_names = ["tagID", "componentID"],column_name='rating')
# Out:
#                                                                 rating
# tagID       componentID
# interactive RobotGeek 180 Degree Robot Servo                         0
#             SparkFun FTDI Basic Breakout - 3.3V                      0
#             Adafruit Pressure/Altitude/Temperature Sensor            0
#             Female Header 20 Position 2 Row (0.1'')                  0
#             SparkFun Breadboard Power Supply 5V/3.3V                 0
# ...                                                                ...
# hat         Capacitor 220 F                                          0
#             ProtoCentral Electronics ProtoCentral Pulse Oxi...       0
#             Graphic OLED 128 x 64                                    0
#             Resistor 100k ohm                                        0
#             Battery Holder 18650 x 2                                 0
#
# [557004 rows x 1 columns]

# %%
predict_and_validate('surprise_tag_comp_test_cut_5_20.csv',sim_options={
            'name': 'msd',
            'user_based': True,
            'min_support':2,
            'shrinkage':0
            },k=100)
# Out:
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# PRECISION: 0.312002892095492
# RECALL: 0.39079086505662447
# RMSE: 1.1359
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# PRECISION: 0.293908765496475
# RECALL: 0.3834328239414199
# RMSE: 1.2373
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# PRECISION: 0.30713949377471955
# RECALL: 0.39325368399508787
# RMSE: 1.4742
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# PRECISION: 0.28852006237184447
# RECALL: 0.3650970328620759
# RMSE: 1.1623
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# PRECISION: 0.2883637460310248
# RECALL: 0.37049219683532003
# RMSE: 2.2013
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# PRECISION: 0.30223808013964276
# RECALL: 0.38715519397826004
# RMSE: 1.1403
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ...

# %%
predict_and_validate('surprise_tag_comp_test_cut_5_20.csv',sim_options={
            'name': 'msd',
            'user_based': True,
            'min_support':2,
            'shrinkage':0
            },k=10, threshold=1)
# Out:
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# PRECISION: 0.11860815481875656
# RECALL: 0.055974067820016064
# RMSE: 0.9839
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# PRECISION: 0.11809989994087416
# RECALL: 0.05185954536500719
# RMSE: 1.3168
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# PRECISION: 0.118366250511666
# RECALL: 0.05374935290621431
# RMSE: 1.1567
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# PRECISION: 0.11200453677172878
# RECALL: 0.05300953812966692
# RMSE: 2.0749
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# PRECISION: 0.11392413699003957
# RECALL: 0.05004646069000533
# RMSE: 1.7390
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# PRECISION: 0.11208896165916224
# RECALL: 0.04843045744008721
# RMSE: 1.0144
# Computing the msd similarity matrix...
# ...

# %%
predictions=get_all_prediction('C:\\progetti\\low-code-ard-proj\\resyduo_components\\transformation_component\\transformation_storage\\surprise_tag_comp_test_2.csv')
# Out:
# Computing the msd similarity matrix...
# Done computing similarity matrix.

# %%
precision,recall,accuracy,fprate = get_precision_recall_accuracy_fprate(predictions, 0.5)
print('precision',precision)
print('recall',recall)
print('accuracy',accuracy)
print('false poisitve rate', fprate)
# Out:
# precision 0.5604395604395604
# recall 0.045987376014427414
# accuracy 0.9825971185392991
# false poisitve rate 0.0006453278265358802

# %%
def precision_recall_at_k(predictions, k=10, threshold=0.5):
    """Return precision and recall at k metrics for each user"""

    # First map the predictions to each user.
    user_est_true = defaultdict(list)
    for  uid,_, true_r, est, _ in predictions:
        user_est_true[uid].append((est, true_r))
    #print(user_est_true)
    #display(user_est_true)

    precisions = dict()
    recalls = dict()
    for uid, user_ratings in user_est_true.items():

        # Sort user ratings by estimated value
        user_ratings.sort(key=lambda x: x[0], reverse=True)

        # Number of relevant items
        n_rel = sum((true_r >= threshold) for (_, true_r) in user_ratings)
        #print('relevant: ',n_rel)

        # Number of recommended items in top k
        n_rec_k = sum((est >= threshold) for (est, _) in user_ratings[:k])
        #print('recommended: ',n_rec_k)

        # Number of relevant and recommended items in top k
        n_rel_and_rec_k = sum(
            ((true_r >= threshold) and (est >= threshold))
            for (est, true_r) in user_ratings[:k]
        )

        # Precision@K: Proportion of recommended items that are relevant
        # When n_rec_k is 0, Precision is undefined. We here set it to 0.

        precisions[uid] = n_rel_and_rec_k / n_rec_k if n_rec_k != 0 else 0

        # Recall@K: Proportion of relevant items that are recommended
        # When n_rel is 0, Recall is undefined. We here set it to 0.

        recalls[uid] = n_rel_and_rec_k / n_rel if n_rel != 0 else 0

    return precisions, recalls

precisions,recalls=precision_recall_at_k(predictions, k=1, threshold=0.5)
print('PRECISION:',sum(prec for prec in precisions.values()) / len(precisions))
print('RECALL:',sum(rec for rec in recalls.values()) / len(recalls))
# Out:
# PRECISION: 0.1452991452991453
# RECALL: 0.06386053667698639

# %%
def get_success_rate(predictions, k=10, threshold=0.5):
    # First map the predictions to each user.
    user_est_true = defaultdict(list)
    for  uid,_, true_r, est, _ in predictions:
        user_est_true[uid].append((est, true_r))
    #print(user_est_true)
    #display(user_est_true)
