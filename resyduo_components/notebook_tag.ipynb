# %%
import pandas as pd
import numpy as np
from IPython.display import display
from data_miner_component.utils import *
from recommender_component import recommender
from data_miner_component import file_reader
from transformation_component.df_utils import DfUtils
from transformation_component.libraries_tranformation import LibraryTranformation
import json
from pandas import DataFrame

# %%
recommender = recommender.Recommender()
file_reader = file_reader.CodeReader()
dfutils = DfUtils()
lib_tranformer = LibraryTranformation()

# %%
dfutils.create_df_from_2_df_col(dfutils.json_df_to_pd_df('C:\\progetti\\low-code-ard-proj\\resyduo_components\\data_miner_component\\data_miner_storage\\json_test.txt'), output_file='C:\\progetti\\low-code-ard-proj\\resyduo_components\\transformation_component\\transformation_storage\\tag_data\\tag_comp_test_3.csv',col_1='tags', col_2 ='components',row_cut=5,col_cut=20)
# Out:
#                         Tactile Switch Top Actuated  Slide Switch  \
# security                                          0             0
# ultrasonic sensor                                 0             0
# tinyml                                            0             0
# tracking                                          0             1
# rgb                                               0             0
# robot                                             0             0
# environmental sensing                             1             0
# machine learning                                  0             0
# art                                               0             0
# embedded                                          0             0
# led                                               2             1
# clocks                                            2             1
# internet of things                                1             0
# robotics                                          0             1
# transportation                                    0             0
# analog                                            0             2
# self balancing robot                              0             0
# games                                             2             0
# cardboard robot                                   0             0
# rfid                                              0             0
# health                                            1             0
# display                                           0             1
# robots                                            0             2
# lora                                              1             0
# remote                                            0             0
# 3d printing                                       0             0
# servo motor                                       0             0
# toys                                              1             3
# sensor                                            0             0
# smart appliances                                  0             0
# high speed photography                            0             0
# cloudgames2022                                    0             0
# remote control                                    0             0
# voice control                                     0             0
# weather                                           1             0
# bluetooth                                         0             0
# audio                                             2             0
# entertainment system                              0             0
# sports                                            0             0
# arduino                                           0             0
# wearables                                         0             0
# music                                             1             0
# data collection                                   0             0
# home automation                                   1             1
# cars                                              0             2
# lights                                            1             1
# monitoring                                        0             3
# lcd                                               0             0
#
#                         Resistor 1k ohm  SG90 Micro-servo motor  \
# security                              0                       2
# ultrasonic sensor                     0                       1
# tinyml                                0                       1
# tracking                              0                       2
# rgb                                   0                       0
# robot                                 1                       3
# environmental sensing                 1                       1
# machine learning                      0                       0
# art                                   0                       1
# embedded                              0                       2
# led                                   1                       0
# clocks                                0                       1
# internet of things                    0                       1
# robotics                              0                       3
# transportation                        0                       0
# analog                                0                       0
# self balancing robot                  0                       1
# games                                 1                       2
# cardboard robot                       0                       1
# rfid                                  0                       0
# health                                0                       0
# display                               0                       0
# robots                                1                       3
# lora                                  0                       0
# remote                                1                       0
# 3d printing                           0                       2
# servo motor                           0                       1
# toys                                  1                       2
# sensor                                1                       0
# smart appliances                      0                       0
# high speed photography                1                       0
# cloudgames2022                        0                       1
# remote control                        0                       2
# voice control                         0                       1
# weather                               0                       0
# bluetooth                             0                       0
# audio                                 1                       0
# entertainment system                  0                       1
# sports                                0                       0
# arduino                               1                       1
# wearables                             0                       2
# music                                 0                       1
# data collection                       0                       0
# home automation                       2                       1
# cars                                  0                       0
# lights                                0                       0
# monitoring                            0                       0
# lcd                                   1                       0
#
#                         Male/Female Jumper Wires  \
# security                                       0
# ultrasonic sensor                              0
# tinyml                                         0
# tracking                                       0
# rgb                                            0
# robot                                          0
# environmental sensing                          1
# machine learning                               0
# art                                            0
# embedded                                       0
# led                                            0
# clocks                                         0
# internet of things                             1
# robotics                                       0
# transportation                                 1
# analog                                         0
# self balancing robot                           0
# games                                          4
# cardboard robot                                0
# rfid                                           0
# health                                         0
# display                                        2
# robots                                         0
# lora                                           0
# remote                                         0
# 3d printing                                    0
# servo motor                                    0
# toys                                           0
# sensor                                         0
# smart appliances                               0
# high speed photography                         0
# cloudgames2022                                 1
# remote control                                 0
# voice control                                  0
# weather                                        0
# bluetooth                                      0
# audio                                          0
# entertainment system                           0
# sports                                         0
# arduino                                        0
# wearables                                      0
# music                                          3
# data collection                                0
# home automation                                1
# cars                                           0
# lights                                         0
# monitoring                                     0
# lcd                                            1
#
#                         Ultrasonic Sensor - HC-SR04 (Generic)  \
# security                                                    0
# ultrasonic sensor                                           1
# tinyml                                                      0
# tracking                                                    1
# rgb                                                         0
# robot                                                       0
# environmental sensing                                       2
# machine learning                                            0
# art                                                         1
# embedded                                                    0
# led                                                         0
# clocks                                                      0
# internet of things                                          3
# robotics                                                    2
# transportation                                              1
# analog                                                      0
# self balancing robot                                        2
# games                                                       1
# cardboard robot                                             1
# rfid                                                        0
# health                                                      0
# display                                                     0
# robots                                                      3
# lora                                                        0
# remote                                                      0
# 3d printing                                                 0
# servo motor                                                 1
# toys                                                        2
# sensor                                                      0
# smart appliances                                            0
# high speed photography                                      0
# cloudgames2022                                              2
# remote control                                              2
# voice control                                               0
# weather                                                     0
# bluetooth                                                   1
# audio                                                       1
# entertainment system                                        0
# sports                                                      0
# arduino                                                     2
# wearables                                                   1
# music                                                       0
# data collection                                             1
# home automation                                             3
# cars                                                        2
# lights                                                      0
# monitoring                                                  0
# lcd                                                         0
#
#                         Arduino Mega 2560  9V 1A Switching Wall Power Supply  \
# security                                1                                  0
# ultrasonic sensor                       1                                  1
# tinyml                                  1                                  0
# tracking                                0                                  0
# rgb                                     0                                  0
# robot                                   2                                  0
# environmental sensing                   1                                  0
# machine learning                        1                                  0
# art                                     1                                  0
# embedded                                1                                  0
# led                                     1                                  1
# clocks                                  1                                  1
# internet of things                      0                                  0
# robotics                                3                                  0
# transportation                          0                                  0
# analog                                  0                                  0
# self balancing robot                    0                                  2
# games                                   1                                  1
# cardboard robot                         0                                  1
# rfid                                    1                                  0
# health                                  1                                  0
# display                                 1                                  0
# robots                                  1                                  2
# lora                                    0                                  0
# remote                                  0                                  0
# 3d printing                             2                                  0
# servo motor                             0                                  1
# toys                                    0                                  0
# sensor                                  1                                  0
# smart appliances                        0                                  0
# high speed photography                  0                                  0
# cloudgames2022                          0                                  0
# remote control                          2                                  1
# voice control                           0                                  0
# weather                                 0                                  0
# bluetooth                               0                                  0
# audio                                   1                                  0
# entertainment system                    1                                  0
# sports                                  0                                  1
# arduino                                 0                                  1
# wearables                               0                                  0
# music                                   1                                  0
# data collection                         0                                  0
# home automation                         0                                  0
# cars                                    1                                  1
# lights                                  0                                  0
# monitoring                              0                                  0
# lcd                                     0                                  0
#
#                         Arduino Opl IoT Kit  PCBWay Custom PCB  ...  \
# security                                  0                  0  ...
# ultrasonic sensor                         0                  0  ...
# tinyml                                    0                  0  ...
# tracking                                  0                  0  ...
# rgb                                       0                  1  ...
# robot                                     1                  0  ...
# environmental sensing                     3                  0  ...
# machine learning                          0                  0  ...
# art                                       0                  0  ...
# embedded                                  0                  2  ...
# led                                       0                  7  ...
# clocks                                    1                  0  ...
# internet of things                       10                  4  ...
# robotics                                  0                  2  ...
# transportation                            1                  0  ...
# analog                                    0                  0  ...
# self balancing robot                      0                  0  ...
# games                                     2                  1  ...
# cardboard robot                           0                  0  ...
# rfid                                      0                  0  ...
# health                                    0                  0  ...
# display                                   0                  3  ...
# robots                                    1                  0  ...
# lora                                      0                  1  ...
# remote                                    0                  0  ...
# 3d printing                               0                  3  ...
# servo motor                               0                  0  ...
# toys                                      0                  0  ...
# sensor                                    0                  3  ...
# smart appliances                          2                  4  ...
# high speed photography                    0                  0  ...
# cloudgames2022                           16                  0  ...
# remote control                            3                  1  ...
# voice control                             0                  0  ...
# weather                                   0                  0  ...
# bluetooth                                 1                  2  ...
# audio                                     0                  1  ...
# entertainment system                      1                  0  ...
# sports                                    0                  0  ...
# arduino                                   0                  1  ...
# wearables                                 0                  1  ...
# music                                     0                  1  ...
# data collection                           1                  1  ...
# home automation                           6                  9  ...
# cars                                      0                  0  ...
# lights                                    2                  4  ...
# monitoring                                2                  0  ...
# lcd                                       0                  0  ...
#
#                         Arduino UNO  Arduino Nano 33 BLE Sense  \
# security                          3                          0
# ultrasonic sensor                 1                          0
# tinyml                            1                          7
# tracking                          2                          0
# rgb                               0                          0
# robot                             0                          0
# environmental sensing             4                          1
# machine learning                  0                          8
# art                               3                          0
# embedded                         11                          4
# led                               6                          0
# clocks                            5                          0
# internet of things                7                          4
# robotics                          7                          2
# transportation                    1                          0
# analog                            2                          0
# self balancing robot              2                          0
# games                            10                          0
# cardboard robot                   1                          0
# rfid                              1                          0
# health                            0                          1
# display                          11                          1
# robots                            7                          0
# lora                              2                          0
# remote                            1                          0
# 3d printing                       0                          0
# servo motor                       1                          0
# toys                              3                          0
# sensor                            2                          0
# smart appliances                  0                          1
# high speed photography            1                          0
# cloudgames2022                    0                          0
# remote control                    3                          0
# voice control                     0                          1
# weather                           0                          1
# bluetooth                         0                          1
# audio                             3                          0
# entertainment system              2                          0
# sports                            1                          0
# arduino                           6                          0
# wearables                         2                          0
# music                             5                          0
# data collection                   3                          1
# home automation                   5                          1
# cars                              4                          0
# lights                            2                          0
# monitoring                        6                          1
# lcd                               8                          0
#
#                         9V battery (generic)  Arduino Nano R3  \
# security                                   0                0
# ultrasonic sensor                          0                0
# tinyml                                     0                0
# tracking                                   0                2
# rgb                                        0                1
# robot                                      0                0
# environmental sensing                      1                5
# machine learning                           0                0
# art                                        0                1
# embedded                                   0                6
# led                                        0               14
# clocks                                     1                3
# internet of things                         1                3
# robotics                                   0                7
# transportation                             0                0
# analog                                     1                2
# self balancing robot                       0                0
# games                                      1                5
# cardboard robot                            0                0
# rfid                                       0                0
# health                                     1                1
# display                                    1                9
# robots                                     0                4
# lora                                       1                0
# remote                                     0                0
# 3d printing                                0                2
# servo motor                                0                0
# toys                                       0                3
# sensor                                     0                5
# smart appliances                           0                9
# high speed photography                     0                0
# cloudgames2022                             0                0
# remote control                             0                3
# voice control                              0                0
# weather                                    1                3
# bluetooth                                  0                1
# audio                                      1                4
# entertainment system                       1                0
# sports                                     0                0
# arduino                                    0                0
# wearables                                  0                4
# music                                      0                3
# data collection                            0                3
# home automation                            0               17
# cars                                       0                0
# lights                                     0                8
# monitoring                                 1                8
# lcd                                        0                0
#
#                         Arduino Nano 33 IoT  Breadboard (generic)  \
# security                                  0                     1
# ultrasonic sensor                         1                     2
# tinyml                                    0                     1
# tracking                                  0                     0
# rgb                                       1                     1
# robot                                     1                     0
# environmental sensing                     0                     1
# machine learning                          1                     1
# art                                       0                     0
# embedded                                  0                     1
# led                                       2                     1
# clocks                                    3                     0
# internet of things                        6                    10
# robotics                                  0                     0
# transportation                            0                     0
# analog                                    0                     0
# self balancing robot                      0                     2
# games                                     0                     2
# cardboard robot                           0                     1
# rfid                                      0                     1
# health                                    0                     0
# display                                   0                     1
# robots                                    1                     2
# lora                                      0                     0
# remote                                    0                     1
# 3d printing                               1                     1
# servo motor                               0                     1
# toys                                      0                     0
# sensor                                    1                     1
# smart appliances                          1                     0
# high speed photography                    0                     0
# cloudgames2022                            1                     0
# remote control                            0                     1
# voice control                             0                     1
# weather                                   0                     0
# bluetooth                                 0                     0
# audio                                     0                     1
# entertainment system                      0                     1
# sports                                    1                     1
# arduino                                   0                     2
# wearables                                 0                     0
# music                                     0                     0
# data collection                           1                     0
# home automation                           2                     1
# cars                                      0                     1
# lights                                    0                     1
# monitoring                                0                     0
# lcd                                       1                     3
#
#                         Jumper wires (generic)  Resistor 220 ohm  \
# security                                     1                 0
# ultrasonic sensor                            2                 0
# tinyml                                       1                 0
# tracking                                     1                 0
# rgb                                          1                 0
# robot                                        1                 0
# environmental sensing                        4                 1
# machine learning                             1                 0
# art                                          1                 0
# embedded                                     6                 0
# led                                          1                 0
# clocks                                       0                 3
# internet of things                          10                 1
# robotics                                     3                 0
# transportation                               1                 0
# analog                                       2                 1
# self balancing robot                         2                 0
# games                                        4                 2
# cardboard robot                              1                 0
# rfid                                         1                 0
# health                                       1                 0
# display                                      2                 1
# robots                                       2                 0
# lora                                         0                 0
# remote                                       1                 0
# 3d printing                                  3                 0
# servo motor                                  1                 0
# toys                                         1                 1
# sensor                                       1                 0
# smart appliances                             3                 0
# high speed photography                       0                 1
# cloudgames2022                               0                 0
# remote control                               5                 0
# voice control                                1                 0
# weather                                      1                 0
# bluetooth                                    1                 0
# audio                                        2                 0
# entertainment system                         2                 1
# sports                                       1                 0
# arduino                                      3                 0
# wearables                                    2                 0
# music                                        1                 0
# data collection                              2                 0
# home automation                              4                 0
# cars                                         1                 0
# lights                                       2                 0
# monitoring                                   2                 0
# lcd                                          4                 1
#
#                         Rotary potentiometer (generic)  LED (generic)
# security                                             1              1
# ultrasonic sensor                                    0              0
# tinyml                                               0              0
# tracking                                             0              0
# rgb                                                  0              0
# robot                                                0              0
# environmental sensing                                0              1
# machine learning                                     0              0
# art                                                  0              0
# embedded                                             0              1
# led                                                  0              2
# clocks                                               0              1
# internet of things                                   1              0
# robotics                                             0              3
# transportation                                       0              0
# analog                                               2              2
# self balancing robot                                 0              0
# games                                                1              0
# cardboard robot                                      0              0
# rfid                                                 1              0
# health                                               0              1
# display                                              2              1
# robots                                               1              0
# lora                                                 0              1
# remote                                               1              1
# 3d printing                                          0              0
# servo motor                                          0              0
# toys                                                 0              2
# sensor                                               1              0
# smart appliances                                     1              0
# high speed photography                               1              1
# cloudgames2022                                       0              1
# remote control                                       1              1
# voice control                                        0              1
# weather                                              0              1
# bluetooth                                            0              0
# audio                                                2              0
# entertainment system                                 0              0
# sports                                               0              0
# arduino                                              0              0
# wearables                                            0              0
# music                                                1              0
# data collection                                      0              0
# home automation                                      1              3
# cars                                                 0              0
# lights                                               0              1
# monitoring                                           0              4
# lcd                                                  2              0
#
# [48 rows x 26 columns]

# %%
dfutils.create_df_from_2_df_col(dfutils.json_df_to_pd_df('json_test.txt'),output_file='tag_comp_test_from_jsontest.csv',col_1='tags', col_2 ='components',row_cut=5,col_cut=10)
# Out:
#                       DHT22 Temperature Sensor  \
# remote control                               1
# machine learning                             0
# 3d printing                                  0
# arduino motor driver                         0
# robot                                        0
# ...                                        ...
# security                                     0
# password                                     0
# app                                          0
# smart fan                                    0
# companion                                    0
#
#                       SparkFun Stepper motor driver board A4988  \
# remote control                                                1
# machine learning                                              0
# 3d printing                                                   2
# arduino motor driver                                          0
# robot                                                         2
# ...                                                         ...
# security                                                      0
# password                                                      0
# app                                                           1
# smart fan                                                     0
# companion                                                     0
#
#                       Li-Ion Battery 1000mAh  Arduino MKR WiFi 1010  \
# remote control                             1                      0
# machine learning                           0                      1
# 3d printing                                0                      1
# arduino motor driver                       0                      0
# robot                                      0                      0
# ...                                      ...                    ...
# security                                   0                      0
# password                                   0                      0
# app                                        0                      0
# smart fan                                  0                      0
# companion                                  0                      0
#
#                       PCBWay Custom PCB  Jumper wires (generic)  \
# remote control                        1                       5
# machine learning                      0                       1
# 3d printing                           3                       3
# arduino motor driver                  0                       1
# robot                                 0                       1
# ...                                 ...                     ...
# security                              0                       1
# password                              0                       1
# app                                   0                       1
# smart fan                             0                       1
# companion                             0                       0
#
#                       USB-A to Micro-USB Cable  Breadboard (generic)  \
# remote control                               0                     1
# machine learning                             0                     1
# 3d printing                                  0                     1
# arduino motor driver                         0                     1
# robot                                        0                     0
# ...                                        ...                   ...
# security                                     1                     1
# password                                     0                     1
# app                                          0                     1
# smart fan                                    0                     0
# companion                                    1                     0
#
#                       Solderless Breadboard Half Size  \
# remote control                                      0
# machine learning                                    0
# 3d printing                                         0
# arduino motor driver                                0
# robot                                               0
# ...                                               ...
# security                                            0
# password                                            0
# app                                                 0
# smart fan                                           0
# companion                                           0
#
#                       Pushbutton Switch Momentary  ...  \
# remote control                                  0  ...
# machine learning                                0  ...
# 3d printing                                     0  ...
# arduino motor driver                            0  ...
# robot                                           0  ...
# ...                                           ...  ...
# security                                        0  ...
# password                                        0  ...
# app                                             0  ...
# smart fan                                       0  ...
# companion                                       0  ...
#
#                       9V 1A Switching Wall Power Supply  \
# remote control                                        1
# machine learning                                      0
# 3d printing                                           0
# arduino motor driver                                  1
# robot                                                 0
# ...                                                 ...
# security                                              0
# password                                              0
# app                                                   1
# smart fan                                             1
# companion                                             0
#
#                       Tactile Switch Top Actuated  Arduino UNO  5 mm LED: Red  \
# remote control                                  0            3              0
# machine learning                                0            0              0
# 3d printing                                     0            0              0
# arduino motor driver                            0            1              0
# robot                                           0            0              0
# ...                                           ...          ...            ...
# security                                        0            3              0
# password                                        0            1              0
# app                                             0            1              0
# smart fan                                       0            1              0
# companion                                       0            0              0
#
#                       Alphanumeric LCD 16 x 2  Arduino Mega 2560  \
# remote control                              0                  2
# machine learning                            0                  1
# 3d printing                                 0                  2
# arduino motor driver                        0                  0
# robot                                       0                  2
# ...                                       ...                ...
# security                                    1                  1
# password                                    1                  0
# app                                         0                  0
# smart fan                                   1                  0
# companion                                   0                  0
#
#                       Slide Switch  DFRobot DFPlayer - A Mini MP3 Player  \
# remote control                   0                                     0
# machine learning                 0                                     0
# 3d printing                      0                                     0
# arduino motor driver             0                                     0
# robot                            0                                     1
# ...                            ...                                   ...
# security                         0                                     0
# password                         0                                     0
# app                              0                                     0
# smart fan                        0                                     0
# companion                        0                                     1
#
#                       Linear Regulator (7805)  Arduino Nano 33 IoT
# remote control                              1                    0
# machine learning                            0                    1
# 3d printing                                 0                    1
# arduino motor driver                        0                    0
# robot                                       0                    1
# ...                                       ...                  ...
# security                                    0                    0
# password                                    0                    0
# app                                         0                    0
# smart fan                                   0                    0
# companion                                   0                    1
#
# [76 rows x 53 columns]

# %%
dfutils.create_df_from_2_df_col(dfutils.json_df_to_pd_df('all_project_detail_final_201022.txt'),output_file='tag_comp_test_cut_5_20.csv',col_1='tags', col_2 ='components',row_cut=5,col_cut=20)
# Out:
#                         RobotGeek 180 Degree Robot Servo  \
# interactive                                            0
# eeg                                                    0
# single board computer                                  0
# seismometer                                            0
# ds3231 alarm interrupt                                 0
# ...                                                  ...
# mofset                                                 0
# astronomical                                           0
# engraving                                              0
# open source                                            0
# hat                                                    0
#
#                         SparkFun FTDI Basic Breakout - 3.3V  \
# interactive                                               0
# eeg                                                       0
# single board computer                                     0
# seismometer                                               0
# ds3231 alarm interrupt                                    0
# ...                                                     ...
# mofset                                                    0
# astronomical                                              0
# engraving                                                 0
# open source                                               0
# hat                                                       1
#
#                         Adafruit Pressure/Altitude/Temperature Sensor  \
# interactive                                                         0
# eeg                                                                 0
# single board computer                                               0
# seismometer                                                         0
# ds3231 alarm interrupt                                              0
# ...                                                               ...
# mofset                                                              0
# astronomical                                                        0
# engraving                                                           0
# open source                                                         0
# hat                                                                 0
#
#                         Female Header 20 Position 2 Row (0.1'')  \
# interactive                                                   0
# eeg                                                           0
# single board computer                                         0
# seismometer                                                   0
# ds3231 alarm interrupt                                        0
# ...                                                         ...
# mofset                                                        0
# astronomical                                                  0
# engraving                                                     0
# open source                                                   0
# hat                                                           0
#
#                         SparkFun Breadboard Power Supply 5V/3.3V  \
# interactive                                                    0
# eeg                                                            0
# single board computer                                          0
# seismometer                                                    0
# ds3231 alarm interrupt                                         0
# ...                                                          ...
# mofset                                                         0
# astronomical                                                   0
# engraving                                                      0
# open source                                                    0
# hat                                                            0
#
#                         RobotGeek Sensor Shield  MOSFET Transistor Switching  \
# interactive                                   0                            0
# eeg                                           0                            0
# single board computer                         0                            0
# seismometer                                   0                            0
# ds3231 alarm interrupt                        0                            0
# ...                                         ...                          ...
# mofset                                        0                            0
# astronomical                                  0                            0
# engraving                                     0                            0
# open source                                   0                            0
# hat                                           0                            0
#
#                         OpenBuilds Micro Limit Switch  \
# interactive                                         0
# eeg                                                 0
# single board computer                               0
# seismometer                                         0
# ds3231 alarm interrupt                              0
# ...                                               ...
# mofset                                              0
# astronomical                                        0
# engraving                                           0
# open source                                         0
# hat                                                 0
#
#                         Helium Starter Kit (LEGACY)  idIoTware Shield  ...  \
# interactive                                       0                 0  ...
# eeg                                               0                 0  ...
# single board computer                             0                 0  ...
# seismometer                                       0                 0  ...
# ds3231 alarm interrupt                            0                 0  ...
# ...                                             ...               ...  ...
# mofset                                            0                 0  ...
# astronomical                                      0                 0  ...
# engraving                                         0                 0  ...
# open source                                       0                 0  ...
# hat                                               0                 0  ...
#
#                         Sewable Conductive Thread  Arduino UNO Wifi Rev.2  \
# interactive                                     1                       0
# eeg                                             0                       0
# single board computer                           0                       0
# seismometer                                     0                       0
# ds3231 alarm interrupt                          0                       0
# ...                                           ...                     ...
# mofset                                          0                       0
# astronomical                                    0                       0
# engraving                                       0                       0
# open source                                     0                       0
# hat                                             0                       0
#
#                         3 mm LED: Red  Arduino Micro  RGB LED  \
# interactive                         0              1        0
# eeg                                 0              0        0
# single board computer               0              0        0
# seismometer                         0              0        0
# ds3231 alarm interrupt              0              0        0
# ...                               ...            ...      ...
# mofset                              0              0        0
# astronomical                        0              0        0
# engraving                           0              0        0
# open source                         0              0        0
# hat                                 0              0        0
#
#                         Capacitor 220 F  \
# interactive                           0
# eeg                                   0
# single board computer                 0
# seismometer                           0
# ds3231 alarm interrupt                0
# ...                                 ...
# mofset                                0
# astronomical                          0
# engraving                             0
# open source                           0
# hat                                   0
#
#                         ProtoCentral Electronics ProtoCentral Pulse Oximeter & Heart Rate Sensor based on MAX30100  \
# interactive                                                             0
# eeg                                                                     0
# single board computer                                                   0
# seismometer                                                             0
# ds3231 alarm interrupt                                                  0
# ...                                                                   ...
# mofset                                                                  0
# astronomical                                                            0
# engraving                                                               0
# open source                                                             0
# hat                                                                     0
#
#                         Graphic OLED 128 x 64  Resistor 100k ohm  \
# interactive                                 0                  0
# eeg                                         0                  0
# single board computer                       0                  0
# seismometer                                 0                  0
# ds3231 alarm interrupt                      0                  0
# ...                                       ...                ...
# mofset                                      0                  0
# astronomical                                0                  0
# engraving                                   0                  0
# open source                                 0                  0
# hat                                         0                  0
#
#                         Battery Holder 18650 x 2
# interactive                                    0
# eeg                                            0
# single board computer                          0
# seismometer                                    0
# ds3231 alarm interrupt                         0
# ...                                          ...
# mofset                                         0
# astronomical                                   0
# engraving                                      0
# open source                                    0
# hat                                            0
#
# [1396 rows x 399 columns]

# %%
dfutils.df_to_surprise_df(input_file='C:\\progetti\\low-code-ard-proj\\resyduo_components\\transformation_component\\transformation_storage\\tag_data\\tag_comp_test_cut_5_20.csv',output_file='C:\\progetti\\low-code-ard-proj\\resyduo_components\\transformation_component\\transformation_storage\\tag_data\\surprise_tag_comp_test_cut_5_20.csv', index_names = ["tagID", "componentID"],column_name='rating')
# Out:
#                                                                 rating
# tagID       componentID
# interactive RobotGeek 180 Degree Robot Servo                         0
#             SparkFun FTDI Basic Breakout - 3.3V                      0
#             Adafruit Pressure/Altitude/Temperature Sensor            0
#             Female Header 20 Position 2 Row (0.1'')                  0
#             SparkFun Breadboard Power Supply 5V/3.3V                 0
# ...                                                                ...
# hat         Capacitor 220 F                                          0
#             ProtoCentral Electronics ProtoCentral Pulse Oxi...       0
#             Graphic OLED 128 x 64                                    0
#             Resistor 100k ohm                                        0
#             Battery Holder 18650 x 2                                 0
#
# [557004 rows x 1 columns]

# %%
recommender.predict_and_validate('surprise_tag_comp_test_cut_5_20.csv',sim_options={
            'name': 'msd',
            'user_based': True,
            'min_support':2,
            'shrinkage':0
            },k=100)
# Out:
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# PRECISION: 0.312002892095492
# RECALL: 0.39079086505662447
# RMSE: 1.1359
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# PRECISION: 0.293908765496475
# RECALL: 0.3834328239414199
# RMSE: 1.2373
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# PRECISION: 0.30713949377471955
# RECALL: 0.39325368399508787
# RMSE: 1.4742
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# PRECISION: 0.28852006237184447
# RECALL: 0.3650970328620759
# RMSE: 1.1623
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# PRECISION: 0.2883637460310248
# RECALL: 0.37049219683532003
# RMSE: 2.2013
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# PRECISION: 0.30223808013964276
# RECALL: 0.38715519397826004
# RMSE: 1.1403
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# PRECISION: 0.30003029570400963
# RECALL: 0.3851634953712318
# RMSE: 0.7942
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# PRECISION: 0.28197236445728546
# RECALL: 0.3652897603828836
# RMSE: 1.1450
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# PRECISION: 0.3041691510376457
# RECALL: 0.38559758452308585
# RMSE: 1.5574
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# PRECISION: 0.28071974418050627
# RECALL: 0.3701534000065517
# RMSE: 1.2370

# %%
recommender.predict_and_validate('surprise_tag_comp_test_cut_5_20.csv',sim_options={
            'name': 'msd',
            'user_based': True,
            'min_support':2,
            'shrinkage':0
            },k=10, threshold=1)
# Out:
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# PRECISION: 0.11860815481875656
# RECALL: 0.055974067820016064
# RMSE: 0.9839
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# PRECISION: 0.11809989994087416
# RECALL: 0.05185954536500719
# RMSE: 1.3168
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# PRECISION: 0.118366250511666
# RECALL: 0.05374935290621431
# RMSE: 1.1567
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# PRECISION: 0.11200453677172878
# RECALL: 0.05300953812966692
# RMSE: 2.0749
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# PRECISION: 0.11392413699003957
# RECALL: 0.05004646069000533
# RMSE: 1.7390
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# PRECISION: 0.11208896165916224
# RECALL: 0.04843045744008721
# RMSE: 1.0144
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# PRECISION: 0.11865619456951831
# RECALL: 0.05104980339737159
# RMSE: 0.9391
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# PRECISION: 0.12271313730840952
# RECALL: 0.05799670302444383
# RMSE: 1.3655
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# PRECISION: 0.12414040114613184
# RECALL: 0.05606123896348849
# RMSE: 1.1008
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# PRECISION: 0.11441448355846641
# RECALL: 0.050876245905157394
# RMSE: 1.4484

# %%
predictions=recommender.get_all_prediction('C:\\progetti\\low-code-ard-proj\\resyduo_components\\transformation_component\\transformation_storage\\tag_data\\surprise_tag_comp_test_2.csv')
# Out:
# Computing the msd similarity matrix...
# Done computing similarity matrix.

# %%
precision,recall,accuracy,fprate = recommender.get_precision_recall_accuracy_fprate(predictions, 0.5)
print('precision',precision)
print('recall',recall)
print('accuracy',accuracy)
print('false poisitve rate', fprate)
# Out:
# precision 0.6111111111111112
# recall 0.6111111111111112
# accuracy 0.6858974358974359
# false poisitve rate 0.26344086021505375

# %%
def tag_data_generator():
    dfutils = df_utils.DfUtils()
    """

    01 df generation

    """
    dfutils.create_df_from_2_df_col(dfutils.json_df_to_pd_df('C:\\progetti\\low-code-ard-proj\\resyduo_components\\data_miner_component\\data_miner_storage\\all_project_detail_final_201022.txt'),
    output_file='C:\\progetti\\low-code-ard-proj\\resyduo_components\\transformation_component\\transformation_storage\\tag_data\\df_tag_comp_cut_5_5.csv',
    col_1='tags',
    col_2 ='components',
    row_cut=5,col_cut=5)

    dfutils.create_df_from_2_df_col(dfutils.json_df_to_pd_df('C:\\progetti\\low-code-ard-proj\\resyduo_components\\data_miner_component\\data_miner_storage\\all_project_detail_final_201022.txt'),
    output_file='C:\\progetti\\low-code-ard-proj\\resyduo_components\\transformation_component\\transformation_storage\\tag_data\\df_tag_comp_cut_5_10.csv',
    col_1='tags',
    col_2 ='components',
    row_cut=5,col_cut=10)

    dfutils.create_df_from_2_df_col(dfutils.json_df_to_pd_df('C:\\progetti\\low-code-ard-proj\\resyduo_components\\data_miner_component\\data_miner_storage\\all_project_detail_final_201022.txt'),
    output_file='C:\\progetti\\low-code-ard-proj\\resyduo_components\\transformation_component\\transformation_storage\\tag_data\\df_tag_comp_cut_0_0.csv',
    col_1='tags',
    col_2 ='components',
    row_cut=0,col_cut=0)


    """

    surprise df generation

    """

    dfutils.df_to_surprise_df(input_file='C:\\progetti\\low-code-ard-proj\\resyduo_components\\transformation_component\\transformation_storage\\tag_data\\df_tag_comp_cut_5_5.csv',
    output_file='C:\\progetti\\low-code-ard-proj\\resyduo_components\\transformation_component\\transformation_storage\\tag_data\\surprise_tag_comp_test_cut_5_5.csv',
    index_names = ["tagID", "componentID"],
    column_name='rating')

    dfutils.df_to_surprise_df(input_file='C:\\progetti\\low-code-ard-proj\\resyduo_components\\transformation_component\\transformation_storage\\tag_data\\df_tag_comp_cut_5_10.csv',
    output_file='C:\\progetti\\low-code-ard-proj\\resyduo_components\\transformation_component\\transformation_storage\\tag_data\\surprise_tag_comp_test_cut_5_10.csv',
    index_names = ["tagID", "componentID"],
    column_name='rating')

    dfutils.df_to_surprise_df(input_file='C:\\progetti\\low-code-ard-proj\\resyduo_components\\transformation_component\\transformation_storage\\tag_data\\df_tag_comp_cut_0_0.csv',
    output_file='C:\\progetti\\low-code-ard-proj\\resyduo_components\\transformation_component\\transformation_storage\\tag_data\\surprise_tag_comp_test_cut_0_0.csv',
    index_names = ["tagID", "componentID"],
    column_name='rating')


tag_data_generator()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_38868\586879544.py in <module>
#      47
#      48
# ---> 49 tag_data_generator()
#
# ~\AppData\Local\Temp\ipykernel_38868\586879544.py in tag_data_generator()
#      44     output_file='C:\\progetti\\low-code-ard-proj\\resyduo_components\\transformation_component\\transformation_storage\\tag_data\\surprise_tag_comp_test_cut_0_0.csv',
#      45     index_names = ["tagID", "componentID"],
# ---> 46     column_name='rating')
#      47
#      48
#
# c:\progetti\low-code-ard-proj\resyduo_components\transformation_component\df_utils.py in df_to_surprise_df(self, input_file, output_file, index_names, column_name)
#      70
#      71     def df_to_surprise_df(self, input_file='json_test.txt',output_file='out.csv',index_names = ["tagID", "componentID"],column_name='rating'):
# ---> 72         df=pd.read_csv(input_file, index_col=0)
#      73         index_1 =df.index
#      74         index_2=df.columns
#
# c:\Users\Skynetth\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# c:\Users\Skynetth\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\io\parsers\readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# c:\Users\Skynetth\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\io\parsers\readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# c:\Users\Skynetth\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\io\parsers\readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# c:\Users\Skynetth\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\io\parsers\readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# c:\Users\Skynetth\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# c:\Users\Skynetth\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\io\parsers\base_parser.py in _open_handles(self, src, kwds)
#     227             memory_map=kwds.get("memory_map", False),
#     228             storage_options=kwds.get("storage_options", None),
# --> 229             errors=kwds.get("encoding_errors", "strict"),
#     230         )
#     231
#
# c:\Users\Skynetth\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     705                 encoding=ioargs.encoding,
#     706                 errors=errors,
# --> 707                 newline="",
#     708             )
#     709         else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\progetti\\low-code-ard-proj\\resyduo_components\\transformation_component\\transformation_storage\\tag_data\\tag_comp_test_cut_0_0.csv'

# %%
tag_comp_predictions=recommender.get_all_prediction('C:\\progetti\\low-code-ard-proj\\resyduo_components\\transformation_component\\transformation_storage\\tag_data\\surprise_tag_comp_cut_5_5.csv')
# Out:
# Computing the msd similarity matrix...
# Done computing similarity matrix.

# %%
display(tag_comp_predictions)
# Out:
# [Prediction(uid='challenge', iid='AllThingsTalk SmartLiving IoT Starter Kit: Arduino Edition', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='raspberrypizero', iid='SG90 Micro-servo motor', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='flashing', iid='Tiny furniture screws', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='freertos', iid='Jumpers', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='dashboard', iid='SparkFun Triple Axis Accelerometer and Gyro Breakout - MPU-6050', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='environment', iid='DFRobot Gravity: Analog Sound Sensor For Arduino', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='dyi', iid='DFRobot Black Gladiator - Tracked Robot Chassis', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='hat', iid='SparkFun microB USB Breakout', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='gate', iid='Through Hole Resistor 20 kohm', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='music', iid='Machine Screw M2', r_ui=1.0, est=0.0724126481638304, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='liquid', iid='Too many cables...', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='i2c lcd', iid='Texas Instruments General Purpose Dual Op-Amp', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='gesture', iid='Lasercut wooden parts', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='iphone control', iid='Capacitor 10 F', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='digital', iid='HX711', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='arduino rover', iid='BD 135 Transistor', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='alarm', iid='DFrobot ASR Board ', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='led level', iid='Arduino motor shield', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='gate', iid='The Tactigon Skin (T-SKIN)', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='electromagnet', iid='TSOP1738 IR receiver', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='cnc_lazer', iid='Heat-shrink tubing', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='wirlesse', iid='USB Buck-Boost Converter Board', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='smartphone', iid='Cat Collar Bell', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='cranial', iid='DC jack and DC plug', r_ui=0.0, est=0.025009882563276076, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='helmet', iid='DFRobot LCD Keypad Shield', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='custom character', iid='Android smart phone', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='robot_car', iid='SparkFun Solder-able Breadboard', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='embrio', iid='LiPo Battery', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='thinger.io', iid='9V to Barrel Jack Connector', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='wallet', iid='Rotary potentiometer (generic)', r_ui=0.0, est=0.17510868883283878, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='clock', iid='Adafruit Motor/Stepper/Servo Shield for Arduino v2 Kit - v2.3', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='portable', iid='Emergency Stop Button', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='arduino projects', iid='SparkFun Logic Level Converter - Bi-Directional', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='networking', iid='Lock nut m3', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='fft', iid='Battery 12V (generic)', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='servomotor', iid='HM-10 Bluetooth module', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='theft alarm', iid='Amazon Alexa Amazon Echo', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='hall effect', iid='8mm pvc pipe 5meter', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='haptics', iid='RobotGeek RFIDuino Shield', r_ui=0.0, est=0.02499982971730445, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='blinky lights', iid='18650 Battery', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='1284p', iid='Raspberry Pi Pico', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='cnc', iid='Infrared LED', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='cascading', iid='Capacitor 33nF', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='chickens', iid='micro:bit BBC micro:bit board', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='twitter', iid='USB Pigtail', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='machine learning', iid='Arduino Ethernet Shield 2', r_ui=1.0, est=0.09959630023453973, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='photo', iid='National Control Devices i2C shield for Arduino UNO', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='diorama', iid='pololu Current Sensor -15.5A to +15.5A', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='brushless_motor', iid='thermistor 10k', r_ui=0.0, est=0.02501647217485429, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='mkr1000', iid='Active Buzzer', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='ecology', iid='webcam', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='garden', iid='5V Battery Pack', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='arduino inclinometer mpu6050', iid='HX711 Module', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='code', iid='AllThingsTalk SmartLiving IoT Starter Kit: Arduino Edition', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='6dof', iid='Arduino Wireless SD Shield', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='nuts and bolts', iid='DFRobot DHT22 Temperature and Humidity Sensor', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='clocks', iid='JustBoom IR Remote', r_ui=1.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='meterelogia', iid='Dot Pcb', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='multifunctional robot', iid='1 channel 5V relay', r_ui=0.0, est=0.02499779704805767, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='indicator', iid='LED ring 12 LEDS Addressable', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='remote', iid='finger clip by Peter Smith', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='debouncing', iid='Speaker: 0.25W 8 ohms', r_ui=0.0, est=0.02499782609225535, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='lights', iid='SparkFun Solder-able Breadboard - Mini', r_ui=2.0, est=0.5563812425335825, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='arduino rover', iid='Robot Chassis', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='squirt', iid='Neoprene', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='legged', iid='IC & Component Socket 14 Contacts', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='costume', iid='Lithium ion battery', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='servo', iid='Enclosure for Arduino Due', r_ui=0.0, est=0.026065019428311124, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='cayenne', iid='OpenBuilds 24V/14.6A Power Supply', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='launch', iid="SparkFun Jumper Wires - Connected 6'' (M/F 20 pack)", r_ui=1.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='resistors', iid='Resistor 100k ohm', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='fimo', iid='SD card reader', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='human machine interface', iid='DAOKI High Sensitivity Sound Microphone Sensor Detection Module For Arduino AVR PIC', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='detection', iid='7-segment display', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='xbox', iid='Soldering tools', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='mit app inventor bluetooth arduino', iid='laser range Sensor 2m', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='sd card', iid='Zerynth Shield', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='transcoder', iid='heatshrink tubing', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='windows remote arduino', iid='HTC Vive Vive', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='color sensor', iid='NEMA 17 stepper motor', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='smartwatches', iid='NTC Thermistor', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='lora projects', iid='SparkFun Button Pad 4x4 - LED Compatible', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='gauge', iid='GY-521 MPU-6050 3 Axis Gyroscope + Accelerometer Module For Arduino', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='fishing', iid='Arduino UNO', r_ui=1.0, est=0.9250650318393892, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='iron', iid='laser range Sensor 2m', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='co2', iid='LattePanda 2GB/32GB (Unactivated)', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='l298 stepper motor driver schematic', iid='Pimoroni wire spool', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='i7sanmachine', iid='Android smart phone', r_ui=0.0, est=0.024994943993538975, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='voltmeter', iid='AR DRONE 2.0', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='transportation', iid='Mini USB Host Shield by DuinoFun', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='sandro mesquita', iid='RobotGeek Slider', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='entertainment system', iid='Buzzer Module', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='pressure sensor', iid='Li-Ion Battery 1000mAh', r_ui=0.0, est=0.024912404317326445, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='electric shock', iid='6m of silicone hose 6x9mm', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='power', iid='Adafruit CC3000 WiFi Module w/UFL antenna', r_ui=0.0, est=0.02494267000411793, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='vibrator', iid='ProtoCentral Electronics ADS1292R ECG/Respiration Shield for Arduino- v2', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='digital spirit level', iid='NeuroSky MindWave', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='ttp223 touch sensor', iid='current sensor sct-013-000', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='fireworks', iid='Linear Solenoid 12 VDC', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='point tracker', iid='Adafruit RTC 3231 Real Time Clock', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='fish', iid='Infrared Emitter 18 ', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='sql', iid='National Control Devices i2C shield for Arduino UNO', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='school', iid='Adafruit RGB LED Strip', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='useless machine', iid='SparkFun CAN-BUS Shield', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='bubbles', iid='TFT shield for Arduino', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='ros', iid='Resistor 100 ohm', r_ui=0.0, est=0.07509250654484304, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='ardumotive', iid='Relay Module (Generic)', r_ui=0.0, est=0.024976049069488807, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='proof of concept', iid='Li-Ion Battery 1000mAh', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='octoprint', iid='Bluetooth Module( HM-10 or Bluefruit)', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='lasers', iid='Through Hole Resistor 2.2 kohm', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='wiring diagram', iid='LED ring 12 LEDS Addressable', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='basic', iid='3V DC Vibrating Motor', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='instrumentation', iid='bolts and nuts', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='telegraph', iid='SmartThings Shield for Arduino', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='password base door lock', iid='Lamp', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='patterns', iid='Infineon Sensor Hub Nano', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='infinity mirror', iid='42BYGHM809 Bi-polar stepper motor', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='ham radio', iid='OpenBuilds 24V/14.6A Power Supply', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='remote sensing', iid='Infineon DC Motor Shield with TLE94112EL for Arduino', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='frequency modulation', iid='Maxim Integrated DS1307 64 x 8 Serial IC Real-Time Clock', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='all you need to know', iid='DFRobot Raspberry Pi 3', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='tutorial', iid='RobotGeek Large Workbench', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='breathalyzer', iid='RGB LED module', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='ups', iid='stepper motor generic', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='mkr', iid='Sony Spresense boards (main & extension)', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='transistor', iid='Atlas Scientific Basic EZO Inline Voltage Isolator', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='transportation', iid='28 pin dip socket', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='raspberrypi3', iid='Reed Switch SPST-NO', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='infrared', iid='Solid and/or stranded core wire (assorted colors)', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='donation machine', iid='RGB Diffused Common Anode', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='plc', iid='Audio / Video Cable Assembly MIDI', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='image processing', iid='Heatsink from PC watercooling', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='useless machine', iid='grow lights', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='test equipment', iid='Copper Tape', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='code', iid='Velcro', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='blind', iid='Capacitor 22 pF', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='c64', iid='LED strips', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='internet of things', iid='30 way FFC Cable', r_ui=1.0, est=0.07591715502770653, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='pebble', iid='Omron Electronic Components LLC Omron Thermal Sensor D6T Series Applied for COVID19', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='cooking', iid='Magnet', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='wireless power', iid='Arduino Nano 33 BLE', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='education', iid='Solar Panel', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='high frequency', iid="Adafruit Quad Alphanumeric Display - White 0.54'' Digits w/ I2C Backpack", r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='ide', iid='2.1x5.5mm jack plug', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='digital spirit level', iid='SparkFun FTDI Basic Breakout - 3.3V', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='actuator', iid='DC Motor', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='nuts and bolts', iid='5v linear regulator', r_ui=0.0, est=0.024993360611166155, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='cm2014-p02', iid='Rocker Switch Non Illuminated', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='gpio', iid='SparkFun MOSFET Power Control Kit', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='ir sensor', iid='RedBearLab BLE Shield', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='toggle', iid='Hw 125 MicroSD Reader', r_ui=0.0, est=0.02492454757628962, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='automatic room light control upon human presence', iid='Delkin Industrial SLC microSD', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='raspberry pi', iid='Arduino MKR WiFi 1010', r_ui=0.0, est=0.024873322746389346, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='microtonal', iid='Graphic OLED 128 x 64', r_ui=0.0, est=0.04996261112506428, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='octoblu', iid='32.768 kHz Crystal', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='chimes', iid='2N2222 transistor', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='simon says', iid='Adafruit Motor Shield V1', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='table', iid='DFRobot DFPlayer - A Mini MP3 Player For Arduino', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='dog', iid='Arduino Wireless Shield (Xbee)', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='interrupts', iid='Particle Argon', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='handwash', iid='DFRobot Gravity: Analog LM35 Temperature Sensor For Arduino', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='battery charger', iid='Seeed Studio Grove - Air quality sensor v1.3', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='txv', iid='Illuminated blue rocker switch', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='petit fs', iid='Led Lamp', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='udp', iid='button', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='onboard computer', iid='Pushbutton Switch Momentary', r_ui=0.0, est=0.050010729671894495, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='remote monitoring', iid='IRF540', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='real-time', iid='Seeed Studio Grove - Touch Sensor SKU 101020037', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='pick and place', iid='Arduino Ethernet Shield 2', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='disability reduction', iid='Brown Dog Gadgets Solar Cockroach Vibrating Disc Motor', r_ui=1.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='vintage', iid='Laser Diode 2 Pins', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='nfc', iid='thermal adhesive', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='tv', iid='Seeed Studio Grove 16x2 LCD (White on Blue)', r_ui=0.0, est=0.024966749439298244, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='arduino robot', iid='SmartThings Samsung SmartThings Water Leak Sensor', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='cloud service', iid='Alphanumeric LCD 16 x 2', r_ui=0.0, est=0.07497821614018245, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='alexa gadget', iid='Nokia 5110 LCD', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='md_max72xx', iid='DHT22 Temperature Sensor', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='pillbox', iid='water level sensor', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='hc-05', iid='Stepper Motor', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='opensource', iid='DFRobot DFPlayer - A Mini MP3 Player For Arduino', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='high frequency', iid='Digilent Voltage Regulator Module', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='glove control', iid='AC/DC Power Supply 12 V', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='ds3231 alarm interrupt', iid='RGB Diffused Common Anode', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='speed control', iid='Panasonic RCA JACK FOR RF OUTPUT CONECTION', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='smartcap', iid='Insulation Tape', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='motion sensor', iid='ProtoCentral Electronics ProtoCentral Pulse Oximeter & Heart Rate Sensor based on MAX30100', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='trenino', iid='High Brightness LED White', r_ui=0.0, est=0.024986040222419126, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='visually', iid='SparkFun Breadboard Power Supply Stick 5V/3.3V', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='arm', iid='DC Power Connector Jack', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='ultrasonic sensor', iid='Resistor 560 ohm', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='motors & robotics', iid='Resistor 10k ohm', r_ui=0.0, est=0.09996833570828144, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='door lock', iid='Drone framesESC battery 11.1V Brushless DC motor', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='sator', iid='SparkFun RFID Reader Breakout', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='photoresistor', iid='Rotary potentiometer (generic)', r_ui=0.0, est=0.12497390696265352, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='pong', iid='electrical tape', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='si4732', iid='Push Button Switch', r_ui=0.0, est=0.024991642844847586, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='how to control fan and light with mobile', iid='ARDUINO ETHERNET SHIELD 2', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='displays', iid='Stepper Motor', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='telegram', iid='Plastic Enclosure Junction Box', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='spi color tft display', iid='Adafruit Monochrome 128x32 I2C OLED graphic display', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='yocto project', iid='DFRobot DFPlayer - A Mini MP3 Player For Arduino', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='arduino control lights wireless', iid='Adafruit Wave Shield', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='blind', iid='Adafruit Joystick', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='artik cloud', iid='pulse sensor', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='handheld', iid='Digilent Voltage Regulator Module', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='solar tracker', iid='Cardboard Box', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='speed meter', iid='16 MHz Crystal', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='simon', iid='Plastic container', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='proof of concept', iid='xbox 360 controller', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='nokia', iid='Arduino Breakout Board', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='autonomous', iid='MICO DTMF Basic Shield for Arduino', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='race track', iid='HDMI cable', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='wheather', iid='button', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='smart building win10', iid='330 Resistor', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='table tenis', iid='LED strip APA102', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='arduino countdown timer relay', iid='MQ7 Gas sensor', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='simulator', iid='Buzzer Module', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='lipo rider', iid='L298N Motor Driver', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='machining', iid='5 Stepper Motors', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='learn', iid='OLED display I2C', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='mpu6050', iid='Solar Panel', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='ultrasonic sensor arduino', iid='Momentary Pushbutton Switch', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='fitness', iid='Stereo audio female plug', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='siemens', iid='Si4730 Radio module', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='attiny', iid='Linear Regulator with Adjustable Output', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='max7219', iid='Tape', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='arudino', iid='Multicolored LED', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='wizwiki-w7500', iid='Adafruit CC3000 WiFi Module w/UFL antenna', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='exercise', iid='2.54_legs_female_12P', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='long range', iid='Arduino Proto Shield', r_ui=0.0, est=0.024975165981791336, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='fm radio', iid='Graphic OLED 128 x 64', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='transistor', iid='Graphic OLED 128 x 64 Pixels', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='coronavirus', iid='I2C LCD 16x2', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='math', iid='NPN Transistor', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='growing', iid='Thermistors', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='maker faire', iid='Seeed Studio Grove - Carbon Dioxide Sensor(MH-Z16)', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='arduino nono', iid='28BYJ-48 Stepper Motor with Driver', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='how to lock an unlock door with bluetooth', iid='Insulating tape', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='595', iid='Arduino Nano', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='messaging', iid='ProtoStax Kit for Momentary Push Button Switches', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='pet', iid='Adafruit 12V 5A switching power supply', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='led transition and sync', iid='Maxim Integrated DS1307 64 x 8 Serial IC Real-Time Clock', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='sql', iid='LattePanda 2GB/32GB (Unactivated)', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='installation', iid='JT2850 RFID module', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='scheduler', iid='MG966R Servo', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='game', iid='Texas Instruments General Purpose Quad Op-Amp', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='androidphone', iid='Plastic box', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='portable', iid='SN74LS47N', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='app', iid='2 channel relay module', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='visual impairment', iid='2.54_male_pins_40', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='ez_sipo8_lib', iid='DC Motor', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='ini-file', iid='JST connectors', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='infrared', iid='SparkFun Single Lead Heart Rate Monitor - AD8232', r_ui=0.0, est=0.023115743850860456, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='mood lamp', iid='ESC 40A', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='mindwave', iid='Simple momentary switch', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='levitation', iid='Digital Radio Receiver', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='fpv', iid='SparkFun Cerberus USB Cable - 6ft', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='optical illusion', iid='Aluminum extrusion', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='eta', iid='10K potentiometer', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='mario', iid='Arduino ADK Rev. 3', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='modular', iid='Connector 3.5 mm (1/8)', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='spotwelding', iid='Thermoelectric Peltier Cooler', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='arduino game', iid='CNY70', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='arcade', iid='Peristaltic pump 12v 7w 11ml/min', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='pc control', iid='Temperature probe', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='halloween', iid='LA38-11 LA38-11BN 22mm button', r_ui=0.0, est=0.024605919315631872, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='run', iid='SparkFun Spectrum Shield', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='tft', iid='TTL Level Shifter ', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='heat', iid='Micro SD Card', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='garage', iid='LDR - Light Dependent Resistor', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='fireworks', iid='SD card module', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='pir sensor', iid='LED Dot Matrix Display Green', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='squirt', iid='Walabot Creator', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='probability', iid='Adafruit 8x8 Bi-color LED Matrix', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='midi', iid='LED Strip NeoPixel Digital RGB', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='animation', iid='Webcam', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='obstacle avoidance', iid='ELEGOO UNO R3 2.8 Inches TFT Touch Screen', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='smart building', iid='6m of silicone hose 6x9mm', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='green-energy', iid='UDOO QUAD', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='papercraft', iid='Seeed Studio Grove - Barometer Sensor (BMP280)', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='broadcast', iid='Amplifier', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='smart glove', iid='IDT Qi 5W Receiver Prototype Kit', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='servomotor', iid='Color Sensor', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='distance measurement', iid='Espressif ESP32S', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='remote sensing', iid='4xAA battery holder', r_ui=0.0, est=0.025045981986403662, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='monitoring', iid='Speaker', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='politekniknegerimadiun', iid='Wood Screws', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='hand gestures', iid="SparkFun Jumper Wires - Connected 6'' (M/F 20 pack)", r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='cw', iid='M2x10 self taping screws', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='fm', iid='BH1750FVI Digital Light Intensity Sensor Module', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='kit', iid='Resistor 560 ohm', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='arduino timer clock', iid='water level sensor', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='amateur radio', iid='Relay Module', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='raspberry pi 2', iid='DC/DC Converter Buck Regulator', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='donation machine', iid='Infrared Receiver 38 kHz', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='sound', iid='Wires in the colors red and black 075mm', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='sourceforge', iid='Infrared Module (Generic)', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='hx711', iid='Arduino Yun Shield', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='trains', iid='SparkFun Low Current Sensor Breakout - ACS712', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='skateboard', iid='Sharp GP2Y0A02YK0F IR Range Sensor  20 cm to 150cm', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='companion', iid='Maxim Integrated MAX7219/MAX7221 LED Display Drivers', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='hobby', iid='SparkFun Power Cell - LiPo Charger/Booster', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='secret code', iid='Teensy 3.6', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='industrial automation', iid='Arduino MKR Zero', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='random', iid='Enclosure for Arduino Due', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='frequency meter', iid='LM2596 Step-Down Adjustable DC-DC Switching Buck Converter', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='simulink', iid='Black foam board (A2 - 5mm thick)', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='helmet', iid='1N5819  1A Schottky Barrier Rectifier', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='lamps', iid='Ethernet Cable Cat6a', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='screen', iid='Relay board', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='modular', iid='Hard disk reading head', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='high speed photography', iid='RGB LCD Shield Kit 16x2 Character Display', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='tune', iid='3.7 volt battery', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='transistors', iid='Tamiya Track and Wheel Set 70100', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='boating', iid='Robotic Arm 6dof model ROT3U', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='study', iid='Modulo Joystick', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='tester', iid="Female Header 8 Position 1 Row (0.1'')", r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='touchscreen', iid='XBee 1mW Wire Antenna  Series 1', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='rov', iid='SparkFun Ultrasonic Sensor - HC-SR04', r_ui=0.0, est=0.02497912484817575, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='cuckoo', iid='Maxim Integrated MAX30100', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='mega2560', iid='MikroE Arduino UNO Click Shield', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='cc3000', iid='stepper motor', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='survival', iid='UTSOURCE Electronic Parts', r_ui=0.0, est=0.024983038257289807, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='skype for business', iid='Push Button', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='mq 5', iid='Fan Accessory AC Motor', r_ui=0.0, est=0.10003125585698155, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='create', iid='RobotGeek Micro USB Cable', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='hdd clock', iid='Wii Nunchuck', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='bluetooth', iid='Potentiometer Slide', r_ui=0.0, est=0.09532027465617451, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='tennis', iid='RobotGeek Panel Mount Dual Power Cable', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='survival', iid='4D Systems gen4-PA', r_ui=0.0, est=0.02498441549522811, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='star trek', iid='DFRobot I2C 16x2 Arduino LCD Display Module', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='arduino shades', iid='BUZZER\t-12MM', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='ssb', iid='wires', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='pillbox', iid='5V - 50W power supply', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='12v', iid='DFRobot Gravity:Digital Push Button (Yellow)', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='sleep tracker', iid='Android Smartphone', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='detector', iid='LED Orange', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='iphone control', iid='Capacitor 100 F', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='image processing', iid='Screw Terminal', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='traffic advisor', iid='MicroSD Module (Generic)', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='fimo', iid='DFRobot Monochrome 0.91128x32 I2C OLED Display with Chip Pad', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='sampling', iid='ControlEverything.com 4-CHANNEL RELAY CONTROLLER FOR I2C', r_ui=0.0, est=0.025025735333087534, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='bme280', iid='DFPlayer Mini', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='ultrasonic sensor', iid='Arduino Wireless Shield (Xbee)', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='servos', iid='Container', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='anime', iid='Aluminum dissipator', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='countdown timer relay using arduino and 16x2 lcd display', iid='Arduino Due', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='squid games', iid='Adafruit Pressure/Altitude/Temperature Sensor', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='indicator', iid='rubber band', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='model', iid='Capacitor 10 pF', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='how to use l298n motor driver', iid='Battery Holder AA x 8', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='repair', iid='usbuart', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='radio', iid='Push button ', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='beginner', iid='Arduino MKR Vidor 4000', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='translator', iid='SparkFun Servo - Generic Metal Gear ', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='scanner', iid='Through Hole Resistor 300 ohm', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='raspberry pi vs arduino', iid='SparkFun Air Quality Breakout - CCS811', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
# ...
#  Prediction(uid='solar', iid='Temperature probe (Generic)', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='infinity mirror', iid='Single Turn Potentiometer- 100k ohms', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='connected devices', iid='SparkFun 32x64 RGB LED P3 Panel', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='smartphone', iid='Adafruit Motor/Stepper/Servo Shield for Arduino v2 Kit - v2.3', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='appliance', iid='DFRobot I2C 16x2 Arduino LCD Display Module', r_ui=0.0, est=0.050022371181063396, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='project', iid='Box', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='sci-fi', iid='IN4001', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='firebase', iid='Arduino Ethernet Shield 2', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='diorama', iid='NodeMCU ESP8266 Breakout Board', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='airsoft time bomb', iid='1N4148  General Purpose Fast Switching', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='matplotlib', iid='Grove Light Sensor', r_ui=0.0, est=0.02498846561337583, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='atmel', iid='RobotGeek Panel Mount Dual Power Cable', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='matplotlib', iid='JT606 RFID antenna', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='alert', iid='RobotGeek Small Workbench', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='diy arduino project', iid='SparkFun Cerberus USB Cable - 6ft', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='programming', iid='Tamiya Universal Plate 70098', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='arduino tutorial', iid='1300 mAh LiPo Battery 7.4V 30C', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='rocket', iid='Digispark Xbee Pro S1 ', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='lock and unlock door with sms', iid='Generic SPST Toggle Switch', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='astronomy', iid='Copper Tape', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='environment', iid='Axial Fan Brushless Motor', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='handwash', iid='Digilent WS2812 Addressable LED Strip', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='dance', iid='JT2850 RFID module', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='ros', iid='Brushless DC Motor', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='control voltage', iid='Seeed Studio Grove - Dust SensorPPD42NS', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='ecology', iid='Brown Dog Gadgets Solar Cockroach Vibrating Disc Motor', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='distance measurement', iid='Ultrasonic Sensor', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='relays', iid='Switch Actuator Head for spring return push-button', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='hydroponics', iid='Alphanumeric LCD 20 x 4', r_ui=0.0, est=0.024991321750881007, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='voice command door lock', iid='USB-A to Micro-USB Cable', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='3d printing', iid='Arduino Ethernet Shield 2', r_ui=0.0, est=0.12451917443683166, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='neopixel', iid='MikroE Arduino UNO Click Shield', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='launch', iid='Raspberry Pi 3 Model B', r_ui=0.0, est=0.04997897316977189, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='metal detector', iid='SparkFun Mini Speaker - PC Mount 12mm 2.048kHz', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='texttospeech', iid='Pimoroni wire spool', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='menu', iid='Resistors capacitors diodes', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='show', iid='Infrared Receiver Head Module LTM-8848-1 Liteon Semiconductors', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='cloudgames2022', iid='Seeed Studio Grove - Carbon Dioxide Sensor(MH-Z16)', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='tft', iid='SparkFun Triple Axis Accelerometer Breakout - ADXL345', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='visualization', iid="8d 2-3/8'' nails ", r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='nodemcu8266', iid='Arduino Micro', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='mkr1000', iid='Remote Control IR 38 Khz and receiver HX1838', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='signal manipulation', iid='2-Way Relay', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='electronicengineering', iid='Infrared Receiver Remote Control', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='magic', iid='e-structure UNO', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='gdb', iid='SSD1306 128x32 i2c Oled display', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='haptics', iid='MQ-135 Gas Sensor - Benzene Alcohol Smoke', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='hcsr04', iid='Soil Moisture Sensor YL-69', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='heating', iid='Espressif Wemos D1 Mini', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='humidity', iid='Load Cell', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='development', iid='Adafruit Lithium Ion Polymer Battery - 3.7v 2500mAh', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='actuator', iid='HX711', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='aerospace', iid='Through Hole Resistor 390 ohm', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='woodworking', iid='thermal adhesive', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='diy countdown timer', iid='Brown Dog Gadgets Solar Cockroach Vibrating Disc Motor', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='introduction', iid='Flash Memory Card SD Card', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='arduinoproject', iid='Adafruit SD card reader', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='hcsr04', iid='USB Buck-Boost Converter Board', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='flying', iid='SparkFun microB USB Breakout', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='meter', iid='Project Box', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='grow', iid='CNY70', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='photogate', iid='DC motor (generic)', r_ui=0.0, est=0.04999307129042969, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='voice control', iid="8d 2-3/8'' nails ", r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='super mario', iid='LidarLite v2', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='covid-19', iid='DC Jack', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='cm2014-p02', iid='color sensor', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='remote controller', iid='SparkFun Logic Level Converter - Bi-Directional', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='mobile app', iid='Cypress CapSense MBR3 Kit', r_ui=0.0, est=0.02653533603815154, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='human detection', iid='Omron Electronic Components LLC Omron Thermal Sensor D6T Series Applied for COVID19', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='magic', iid='High Brightness LED Color', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='dice', iid='Insulating tape', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='exercise', iid='HiFiBerry AMP2', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='analog meters', iid='LCD Shield', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='monitor', iid='SG90 Micro-servo motor', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='logic board', iid='Male/Female Jumper Wires', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='distance measurement', iid='Adafruit TB6612 1.2A DC/Stepper Motor Driver Breakout Board', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='physical computing', iid='OpenBuilds Ball Bearing  625 2RS 5x16x5', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='arduino real time clock ds3231 with lcd display', iid='USB-A to Micro-USB Cable', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='universal remote', iid='GY-906-BCC IR Infrared Thermometry Module', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='home security', iid='Push Button', r_ui=0.0, est=0.025025747221038282, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='introduction', iid='Arduino Wireless Shield (Xbee)', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='laundry', iid='LM35', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='smart', iid='Arduino MKR IoT Bundle', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='diecast', iid='2N3904 transistor', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='digital spirit level', iid='DC jack and DC plug', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='programmer', iid='LED Orange', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='compass', iid='Lipo Battery 3S 11.1-12.6V 1300mAh 25C', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='mpu-9250', iid='Infrared Module (Generic)', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid="''internet of things''", iid='180 Ohm 220 Ohm and 1k Ohm resistor', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='ios', iid='SparkFun Nokia 5110 Screen', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='microsoft cognitive services', iid='MQ-135 Air Quality Detector Sensor', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='vfd display', iid='Tube Nozzle', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='mobile app', iid='Helium Atom Xbee Module', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='ground', iid='UTSOURCE Electronic Parts', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='animation', iid='DFRobot 16x2 1602 LCD Keypad Shield For Arduino', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='console', iid='Temp', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='physics', iid='Arduino MKR WAN 1300', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='airsoft', iid='5V Relay', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='automatic room light controller', iid='SparkFun LED Array - 8x7', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='lm35sensor', iid='Solenoid Valve 2 Way', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='synth', iid='L298n Motor Driver', r_ui=0.0, est=0.04995324054960116, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='ac', iid='LED Blue Green', r_ui=0.0, est=0.024986676977381234, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='tactile', iid='Resistor 4.7K ohm', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='wizwiki-w7500', iid='RobotGeek DC Squid Cable', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='sipo8', iid='RGB LED', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='mammal', iid='HM-10 BLE Bluetooth 4.0 CC2540 CC2541 Serial Wireless Module', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='fm radio', iid='SparkFun XBee Explorer Regulated', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='morse code', iid='Resistor 221 ohm', r_ui=1.0, est=0.049994401044979216, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='gsm module', iid='Photodiode 45 ', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='starter', iid='Arduino Zero', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='led cube', iid='Seeed Studio Base Shield V2', r_ui=0.0, est=0.024952949767364844, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='chat', iid='Zip Ties', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='fireworks', iid='405x405mm white acrylic glass', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='cosplay', iid='RobotGeek DC Power Squid', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='audio sampling', iid='push buttons', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='pressure', iid='Through Hole Resistor 10 ohm', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='stabila 196-2 electronic level', iid='Android device', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='fingerprint', iid='copper tape', r_ui=0.0, est=0, details={'actual_k': 40, 'was_impossible': False}),
#  ...]

# %%
top_n_recommendations=recommender.get_top_n(predictions=tag_comp_predictions,n=10)

# %%
display(top_n_recommendations)
# Out:
# defaultdict(list,
#             {'challenge': [('Arduino Nano R3', 0.3001, 0.0),
#               ('Resistor 220 ohm', 0.3, 1.0),
#               ('Photo resistor', 0.1, 0.0),
#               ('General Purpose Transistor NPN', 0.075, 0.0),
#               ('Digilent 5V 2.5A Switching Power Supply', 0.075, 0.0),
#               ('Digilent IR Proximity Sensor', 0.05, 0.0),
#               ('Bluetooth Low Energy (BLE) Module (Generic)', 0.05, 0.0),
#               ('LED Light Bulb Frosted GLS', 0.05, 0.0),
#               ('Arduino Due', 0.05, 0.0),
#               ('Female/Female Jumper Wires', 0.05, 0.0)],
#              'raspberrypizero': [('Arduino Nano R3', 0.0749, 0.0),
#               ("0.96'' 128x64 OLED I2C Display", 0.025, 0.0),
#               ('Arduino Leonardo', 0.025, 0.0),
#               ('BH1750FVI Digital Light Intensity Sensor Module', 0.025, 0.0),
#               ('SparkFun LilyPad Coin Cell Battery Holder - Switched - 20mm',
#                0.025,
#                0.0),
#               ('SparkFun LilyPad LED White (5pcs)', 0.025, 0.0),
#               ('7 Segment LED Display InfoVue', 0.025, 0.0),
#               ('Arduino Proto Shield', 0.025, 0.0),
#               ('SG90 Micro-servo motor', 0, 0.0),
#               ('Proximity sensor', 0, 0.0)],
#              'flashing': [('Arduino UNO', 0.9251, 1.0),
#               ('Ultrasonic Sensor - HC-SR04 (Generic)', 0.2, 0.0),
#               ('Alphanumeric LCD 16 x 2', 0.1749, 0.0),
#               ('9V battery (generic)', 0.1501, 0.0),
#               ('USB-A to B Cable', 0.125, 0.0),
#               ('9V Battery Clip', 0.1001, 0.0),
#               ('SG90 Micro-servo motor', 0.1001, 0.0),
#               ('Resistor 100 ohm', 0.1, 0.0),
#               ('DHT11 Temperature & Humidity Sensor (4 pins)', 0.1, 0.0),
#               ('DS3231 AT24C32 11C real time clock module', 0.0755, 1.0)],
#              'freertos': [('Arduino Nano R3', 0.275, 0.0),
#               ('MAX9814', 0.15, 1.0),
#               ('Alphanumeric LCD 16 x 2', 0.125, 0.0),
#               ('Goldilocks Analogue', 0.125, 1.0),
#               ('Arduino Leonardo', 0.075, 0.0),
#               ('DFRobot I2C 16x2 Arduino LCD Display Module', 0.05, 0.0),
#               ('HC-06 Bluetooth Module', 0.05, 0.0),
#               ('Rotary Encoder with Push-Button', 0.05, 0.0),
#               ('UTSOURCE Electronic Parts', 0.05, 0.0),
#               ('Arduino Due', 0.025, 0.0)],
#              'dashboard': [('5 mm LED: Red', 0.475, 0.0),
#               ('Resistor 220 ohm', 0.475, 0.0),
#               ('Buzzer', 0.45, 0.0),
#               ('Solderless Breadboard Full Size', 0.125, 0.0),
#               ('Particle Photon', 0.0501, 0.0),
#               ('Arduino Uno', 0.05, 0.0),
#               ('DFRobot I2C 16x2 Arduino LCD Display Module', 0.05, 0.0),
#               ('DHT11 Temperature & Humidity Sensor (4 pins)', 0.05, 0.0),
#               ('PIR Motion Sensor (generic)', 0.05, 0.0),
#               ('UTSOURCE Electronic Parts', 0.05, 0.0)],
#              'environment': [('Breadboard (generic)', 0.425, 0.0),
#               ('Buzzer', 0.3249, 0.0),
#               ('Resistor 220 ohm', 0.2, 0.0),
#               ('Resistor 330 ohm', 0.15, 0.0),
#               ('Arduino MKR Fox 1200', 0.0751, 1.0),
#               ('Geared DC Motor 12 V', 0.075, 0.0),
#               ('Resistor 1k ohm', 0.075, 0.0),
#               ('9V 1A Switching Wall Power Supply', 0.075, 0.0),
#               ('Adafruit motorshield V1', 0.05, 0.0),
#               ('AA Batteries', 0.05, 0.0)],
#              'dyi': [('Arduino UNO', 0.5749, 0.0),
#               ('Resistor 10k ohm', 0.2999, 0.0),
#               ('5 mm LED: Red', 0.25, 0.0),
#               ('Ultrasonic Sensor - HC-SR04 (Generic)', 0.1999, 0.0),
#               ('Capacitor 100 nF', 0.1999, 0.0),
#               ('5 mm LED: Green', 0.15, 0.0),
#               ('Resistor 1k ohm', 0.1499, 0.0),
#               ('Rotary potentiometer (generic)', 0.125, 0.0),
#               ('Adafruit RGB Backlight LCD - 16x2', 0.1, 0.0),
#               ('32x8 LED matrix display', 0.075, 0.0)],
#              'hat': [('Jumper wires (generic)', 0.4001, 0.0),
#               ('Resistor 10k ohm', 0.275, 0.0),
#               ('Ultrasonic Sensor - HC-SR04 (Generic)', 0.125, 0.0),
#               ('Resistor 330 ohm', 0.1, 0.0),
#               ('Hook Up Wire Kit 22 AWG', 0.075, 0.0),
#               ('12 volt 40 AMPS DC Power supply', 0.075, 0.0),
#               ('Photo resistor', 0.075, 0.0),
#               ('Wires', 0.075, 0.0),
#               ('Slide Switch', 0.075, 0.0),
#               ('DHT11 Temperature & Humidity Sensor (4 pins)', 0.075, 0.0)],
#              'gate': [('Buzzer', 0.45, 0.0),
#               ('Ultrasonic Sensor - HC-SR04 (Generic)', 0.425, 0.0),
#               ('5 mm LED: Red', 0.4, 0.0),
#               ('LED (generic)', 0.125, 1.0),
#               ('5 mm LED: Green', 0.1, 0.0),
#               ('Geared DC Motor 12 V', 0.05, 0.0),
#               ('Arduino Due', 0.05, 0.0),
#               ('LED Blue Green', 0.05, 0.0),
#               ('BD139 Transistor', 0.05, 0.0),
#               ('Darlington High Power Transistor', 0.025, 0.0)],
#              'music': [('Arduino UNO', 46.145, 122.0),
#               ('LED (generic)', 9.9633, 27.0),
#               ('Resistor 10k ohm', 6.7101, 26.0),
#               ('HC-05 Bluetooth Module', 5.1947, 1.0),
#               ('Rotary potentiometer (generic)', 3.2736, 32.0),
#               ('Arduino MKR1000', 3.1352, 2.0),
#               ('DHT22 Temperature Sensor', 3.0376, 0.0),
#               ('9V battery (generic)', 2.9769, 5.0),
#               ('USB-A to B Cable', 2.2454, 6.0),
#               ('Servos (Tower Pro MG996R)', 2.0348, 1.0)],
#              'liquid': [('Breadboard (generic)', 0.3249, 0.0),
#               ('Arduino Mega 2560', 0.225, 0.0),
#               ('Arduino Nano R3', 0.1251, 0.0),
#               ('Resistor 220 ohm', 0.125, 0.0),
#               ('HC-05 Bluetooth Module', 0.1, 0.0),
#               ('Solderless Breadboard Full Size', 0.1, 0.0),
#               ('RobotGeek Silicone Tubing', 0.0754, 2.0),
#               ('Rotary potentiometer (generic)', 0.0751, 0.0),
#               ('Slide Switch', 0.075, 0.0),
#               ('DC motor (generic)', 0.0749, 0.0)],
#              'i2c lcd': [('Arduino UNO', 0.9501, 1.0),
#               ('Buzzer', 0.175, 0.0),
#               ('Rotary potentiometer (generic)', 0.1499, 0.0),
#               ('Male/Female Jumper Wires', 0.0751, 1.0),
#               ('5 mm LED: Red', 0.075, 0.0),
#               ('9V 1A Switching Wall Power Supply', 0.075, 0.0),
#               ('Geared DC Motor 12 V', 0.075, 0.0),
#               ('Solder', 0.05, 0.0),
#               ('Resistor 470 ohm', 0.05, 0.0),
#               ('Tactile Switch Top Actuated', 0.0251, 1.0)],
#              'gesture': [('Jumper wires (generic)', 0.7024, 6.0),
#               ('Resistor 10k ohm', 0.2997, 0.0),
#               ('Resistor 1k ohm', 0.2507, 1.0),
#               ('Arduino Mega 2560', 0.1007, 0.0),
#               ('Microchip ATtiny85', 0.0998, 0.0),
#               ('SparkFun Pushbutton switch 12mm', 0.0753, 1.0),
#               ('Adafruit Standard LCD - 16x2 White on Blue', 0.0748, 1.0),
#               ('UTSOURCE Electronic Parts', 0.0508, 1.0),
#               ('GY-521 MPU-6050 3 Axis Gyroscope + Accelerometer Module For Arduino',
#                0.0508,
#                2.0),
#               ('5 mm LED: Red', 0.0504, 0.0)],
#              'iphone control': [('Jumper wires (generic)', 0.5249, 0.0),
#               ('Breadboard (generic)', 0.375, 0.0),
#               ('Buzzer', 0.2, 0.0),
#               ('9V battery (generic)', 0.1, 0.0),
#               ('Rotary potentiometer (generic)', 0.075, 0.0),
#               ('SparkFun Stepper motor driver board A4988', 0.075, 0.0),
#               ('Espressif ESP8266 ESP-01', 0.075, 0.0),
#               ('USB-A to B Cable', 0.0749, 0.0),
#               ('Leap Motion Controller', 0.0503, 1.0),
#               ('OpenBuilds NEMA 17 Stepper Motor', 0.05, 0.0)],
#              'digital': [('Breadboard (generic)', 0.5998, 1.0),
#               ('HC-05 Bluetooth Module', 0.1251, 0.0),
#               ('Photo resistor', 0.1, 0.0),
#               ('Resistor 4.75k ohm', 0.075, 0.0),
#               ('Espressif ESP8266 ESP-01', 0.075, 0.0),
#               ('Thermistor', 0.0749, 0.0),
#               ('USB-A to Micro-USB Cable', 0.0501, 0.0),
#               ('9V 1A Switching Wall Power Supply', 0.0501, 0.0),
#               ('Bolt IoT Bolt WiFi Module', 0.05, 0.0),
#               ('Tactile Switch Top Actuated', 0.05, 0.0)],
#              'arduino rover': [('Ultrasonic Sensor - HC-SR04 (Generic)',
#                0.4,
#                1.0),
#               ('Resistor 10k ohm', 0.225, 0.0),
#               ('HC-05 Bluetooth Module', 0.175, 0.0),
#               ('Resistor 221 ohm', 0.1, 0.0),
#               ('Slide Switch', 0.05, 0.0),
#               ('1Sheeld', 0.05, 0.0),
#               ('Female/Female Jumper Wires', 0.05, 0.0),
#               ('Solderless Breadboard Half Size', 0.05, 0.0),
#               ('Male/Female Jumper Wires', 0.05, 0.0),
#               ('RGB Diffused Common Cathode', 0.05, 0.0)],
#              'alarm': [('Breadboard (generic)', 1.3753, 5.0),
#               ('LED (generic)', 0.8475, 3.0),
#               ('Arduino Mega 2560', 0.7475, 1.0),
#               ('Resistor 221 ohm', 0.4717, 2.0),
#               ('Alphanumeric LCD 16 x 2', 0.2748, 0.0),
#               ('1Sheeld', 0.2495, 2.0),
#               ('SG90 Micro-servo motor', 0.178, 1.0),
#               ('Arduino 101', 0.1737, 0.0),
#               ('IR receiver (generic)', 0.1491, 2.0),
#               ('UTSOURCE Electronic Parts', 0.1485, 0.0)],
#              'led level': [('Resistor 100 ohm', 0.4259, 1.0),
#               ('Jumper wires (generic)', 0.1997, 0.0),
#               ('Raspberry Pi 2 Model B', 0.0749, 0.0),
#               ('Espressif ESP8266 ESP-01', 0.0749, 0.0),
#               ('9V Battery Clip', 0.0749, 0.0),
#               ('DHT22 Temperature Sensor', 0.0749, 0.0),
#               ('MLX90641', 0.0499, 0.0),
#               ('Container', 0.025, 0.0),
#               ('313 RPM HD Precision Planetary Gear Motor', 0.025, 0.0),
#               ('Capacitor 22 F', 0.025, 0.0)],
#              'electromagnet': [('Jumper wires (generic)', 0.425, 0.0),
#               ('Arduino Nano R3', 0.1749, 0.0),
#               ('Solderless Breadboard Full Size', 0.1251, 0.0),
#               ('Resistor 1k ohm', 0.0999, 0.0),
#               ('Relay Module (Generic)', 0.075, 0.0),
#               ('Arduino Micro', 0.075, 0.0),
#               ('Li-po battery', 0.05, 0.0),
#               ('9V Battery Clip', 0.05, 0.0),
#               ('A shell', 0.05, 0.0),
#               ('Temperature Sensor', 0.05, 0.0)],
#              'cnc_lazer': [('Arduino UNO', 0.9002, 1.0),
#               ('Solderless Breadboard Full Size', 0.3249, 0.0),
#               ('SparkFun Stepper motor driver board A4988', 0.3003, 1.0),
#               ('Alphanumeric LCD 16 x 2', 0.3, 0.0),
#               ('Male/Female Jumper Wires', 0.175, 0.0),
#               ('Arduino Mega 2560', 0.1749, 0.0),
#               ('Resistor 10k ohm', 0.15, 0.0),
#               ('9V battery (generic)', 0.1499, 0.0),
#               ('Relay Module (Generic)', 0.125, 0.0),
#               ('Resistor 330 ohm', 0.125, 0.0)],
#              'wirlesse': [('Breadboard (generic)', 0.2998, 0.0),
#               ('Rotary potentiometer (generic)', 0.225, 1.0),
#               ('Alphanumeric LCD 16 x 2', 0.1752, 1.0),
#               ('Resistor 100 ohm', 0.125, 0.0),
#               ('5 mm LED: Red', 0.125, 0.0),
#               ('Capacitor 1000 F', 0.075, 0.0),
#               ('Arduino Mega 2560', 0.075, 0.0),
#               ('Resistor 221 ohm', 0.075, 0.0),
#               ('Resistor 221k ohm', 0.0501, 0.0),
#               ('Resistor 100k ohm', 0.05, 0.0)],
#              'smartphone': [('Jumper wires (generic)', 0.9735, 5.0),
#               ('Arduino Mega 2560', 0.3994, 2.0),
#               ('Rotary potentiometer (generic)', 0.3986, 0.0),
#               ('Resistor 10k ohm', 0.2996, 1.0),
#               ('Solderless Breadboard Full Size', 0.0998, 0.0),
#               ('SparkFun Arduino Pro Mini 328 - 5V/16MHz', 0.0753, 0.0),
#               ('Raspberry Pi 3 Model B', 0.0749, 0.0),
#               ('16 MHz Crystal', 0.0748, 0.0),
#               ('Capacitor 10 F', 0.0748, 0.0),
#               ('Hall Effect Sensor', 0.0505, 0.0)],
#              'cranial': [('Buzzer', 0.275, 0.0),
#               ('5 mm LED: Red', 0.225, 0.0),
#               ('Ultrasonic Sensor - HC-SR04 (Generic)', 0.175, 0.0),
#               ('Rotary potentiometer (generic)', 0.15, 1.0),
#               ('5 mm LED: Yellow', 0.15, 0.0),
#               ('LED Blue', 0.1, 0.0),
#               ('1N4007  High Voltage High Current Rated Diode', 0.0751, 1.0),
#               ('DFRobot 6 DOF Sensor - MPU6050', 0.075, 0.0),
#               ('Screws', 0.075, 0.0),
#               ('Arduino Leonardo', 0.05, 0.0)],
#              'helmet': [('Alphanumeric LCD 16 x 2', 0.1501, 0.0),
#               ('9V Battery Clip', 0.15, 0.0),
#               ('Solderless Breadboard Full Size', 0.125, 0.0),
#               ('Resistor 100 ohm', 0.1, 0.0),
#               ('Arduino Micro', 0.1, 0.0),
#               ('Slide Switch', 0.1, 0.0),
#               ('Gear motor', 0.075, 0.0),
#               ('DHT11 Temperature & Humidity Sensor (4 pins)', 0.075, 0.0),
#               ('DFRobot 6 DOF Sensor - MPU6050', 0.075, 0.0),
#               ('Linear Regulator (7805)', 0.075, 0.0)],
#              'custom character': [('Ultrasonic Sensor - HC-SR04 (Generic)',
#                0.25,
#                0.0),
#               ('Arduino Nano R3', 0.2249, 0.0),
#               ('Resistor 10k ohm', 0.2249, 0.0),
#               ('5 mm LED: Red', 0.1499, 0.0),
#               ('Resistor 330 ohm', 0.1, 0.0),
#               ('SG90 Micro-servo motor', 0.0751, 0.0),
#               ('Texas Instruments Dual H-Bridge motor drivers L293D',
#                0.075,
#                0.0),
#               ('Perma-Proto Breadboard Half Size', 0.075, 0.0),
#               ('Rotary potentiometer (generic)', 0.075, 0.0),
#               ('BD139 Transistor', 0.05, 0.0)],
#              'robot_car': [('Arduino UNO', 1.075, 1.0),
#               ('HC-05 Bluetooth Module', 0.2254, 1.0),
#               ('Solderless Breadboard Full Size', 0.2249, 0.0),
#               ('LED Light Bulb Frosted GLS', 0.1499, 0.0),
#               ('Relay Module (Generic)', 0.1499, 0.0),
#               ('SG90 Micro-servo motor', 0.1, 0.0),
#               ('Rotary Encoder with Push-Button', 0.075, 0.0),
#               ('Servos (Tower Pro MG996R)', 0.05, 0.0),
#               ('Fan Accessory AC Motor', 0.05, 0.0),
#               ('Slide Switch', 0.0499, 0.0)],
#              'embrio': [('Ultrasonic Sensor - HC-SR04 (Generic)', 0.4, 0.0),
#               ('Buzzer', 0.375, 0.0),
#               ('5 mm LED: Red', 0.325, 0.0),
#               ('Rotary potentiometer (generic)', 0.1, 0.0),
#               ('Resistor 1k ohm', 0.075, 0.0),
#               ('Thermistor', 0.05, 0.0),
#               ('RobotGeek RFIDuino Shield', 0.025, 0.0),
#               ('Resistor 4.75k ohm', 0.025, 0.0),
#               ('ORICO Bluetooth module', 0.025, 0.0),
#               ('313 RPM HD Precision Planetary Gear Motor', 0.025, 0.0)],
#              'thinger.io': [('Arduino UNO', 1.0001, 0.0),
#               ('Buzzer', 0.4, 0.0),
#               ('Resistor 330 ohm', 0.15, 0.0),
#               ('Photo resistor', 0.075, 0.0),
#               ('USB-A to B Cable', 0.075, 0.0),
#               ('Digilent IR Proximity Sensor', 0.075, 0.0),
#               ('5 mm LED: Green', 0.0749, 0.0),
#               ('Pushbutton Switch Push-Pull', 0.05, 0.0),
#               ('Resistor 100 ohm', 0.05, 0.0),
#               ('AA Batteries', 0.05, 0.0)],
#              'wallet': [('Arduino UNO', 0.9001, 1.0),
#               ('Rotary potentiometer (generic)', 0.1751, 0.0),
#               ('General Purpose Transistor NPN', 0.125, 0.0),
#               ('Adafruit RGB Backlight LCD - 16x2', 0.0751, 0.0),
#               ('1N4007  High Voltage High Current Rated Diode', 0.075, 0.0),
#               ('USB-A to B Cable', 0.075, 0.0),
#               ('Solderless Breadboard Full Size', 0.075, 0.0),
#               ('LED Light Bulb Frosted GLS', 0.05, 0.0),
#               ('Linear Regulator (7805)', 0.05, 0.0),
#               ('Single Turn Potentiometer- 100k ohms', 0.05, 0.0)],
#              'clock': [('Arduino Nano R3', 0.7234, 8.0),
#               ('Ultrasonic Sensor - HC-SR04 (Generic)', 0.3742, 0.0),
#               ('Resistor 220 ohm', 0.3002, 0.0),
#               ('Alphanumeric LCD 16 x 2', 0.2237, 0.0),
#               ('9V battery (generic)', 0.1497, 0.0),
#               ('Resistor 100 ohm', 0.1497, 0.0),
#               ('SparkFun Arduino Pro Mini 328 - 5V/16MHz', 0.1247, 0.0),
#               ('Alphanumeric LCD 20 x 4', 0.0997, 0.0),
#               ('Linear Regulator (7805)', 0.0747, 0.0),
#               ('SparkFun CAN-BUS Shield', 0.0503, 0.0)],
#              'portable': [('Jumper wires (generic)', 1.074, 4.0),
#               ('LED (generic)', 0.5245, 1.0),
#               ('Ultrasonic Sensor - HC-SR04 (Generic)', 0.2746, 1.0),
#               ('HC-05 Bluetooth Module', 0.2001, 1.0),
#               ('9V Battery Clip', 0.1247, 0.0),
#               ('Rotary Encoder with Push-Button', 0.075, 0.0),
#               ('Arduino MKR1000', 0.0748, 0.0),
#               ('USB-A to B Cable', 0.0748, 0.0),
#               ('3 mm LED: Red', 0.0748, 0.0),
#               ('DHT22 Temperature Sensor', 0.0748, 0.0)],
#              'arduino projects': [('Breadboard (generic)', 0.65, 3.0),
#               ('Jumper wires (generic)', 0.45, 2.0),
#               ('Ultrasonic Sensor - HC-SR04 (Generic)', 0.2999, 1.0),
#               ('Resistor 221 ohm', 0.125, 1.0),
#               ('Male/Female Jumper Wires', 0.1001, 1.0),
#               ('Texas Instruments Dual H-Bridge motor drivers L293D',
#                0.0999,
#                0.0),
#               ('Arduino Leonardo', 0.075, 0.0),
#               ('PIR Motion Sensor (generic)', 0.075, 0.0),
#               ('Temperature Sensor', 0.0749, 0.0),
#               ('Resistor 100 ohm', 0.05, 0.0)],
#              'networking': [('Resistor 220 ohm', 0.3501, 0.0),
#               ('LED (generic)', 0.125, 1.0),
#               ('Resistor 330 ohm', 0.1, 0.0),
#               ('DC motor (generic)', 0.0999, 0.0),
#               ('Solderless Breadboard Full Size', 0.075, 0.0),
#               ('resistors and capacitors', 0.0501, 0.0),
#               ('Arduino Yun', 0.05, 0.0),
#               ('Arduino 101', 0.05, 0.0),
#               ('SparkFun Pushbutton switch 12mm', 0.05, 0.0),
#               ('Bluetooth Low Energy (BLE) Module (Generic)', 0.05, 0.0)],
#              'fft': [('Breadboard (generic)', 0.375, 0.0),
#               ('Resistor 1k ohm', 0.1749, 0.0),
#               ('Resistor 330 ohm', 0.15, 0.0),
#               ('OpenBuilds NEMA 17 Stepper Motor', 0.1251, 0.0),
#               ('Ultrasonic Sensor - HC-SR04 (Generic)', 0.125, 0.0),
#               ('Adafruit NeoPixel Ring: WS2812 5050 RGB LED', 0.1001, 0.0),
#               ('Arduino Micro', 0.075, 0.0),
#               ('Arduino MKR1000', 0.05, 0.0),
#               ('DHT11 Temperature & Humidity Sensor (4 pins)', 0.05, 0.0),
#               ('Temperature Sensor', 0.05, 0.0)],
#              'servomotor': [('Buzzer', 0.4249, 0.0),
#               ('Arduino Leonardo', 0.0749, 0.0),
#               ('Mini Solar Panel', 0.0503, 1.0),
#               ('hydroponic drip system', 0.05, 0.0),
#               ('Flash Memory Card MicroSD Card', 0.05, 0.0),
#               ('Relayr WunderBar', 0.05, 0.0),
#               ('1N4007  High Voltage High Current Rated Diode', 0.0499, 0.0),
#               ('Female/Female Jumper Wires', 0.025, 0.0),
#               ('MQ4 Gas sensor', 0.025, 0.0),
#               ('BD139 Transistor', 0.025, 0.0)],
#              'theft alarm': [('Arduino UNO', 0.9501, 1.0),
#               ('Solderless Breadboard Full Size', 0.2252, 1.0),
#               ('Alphanumeric LCD 16 x 2', 0.225, 0.0),
#               ('Buzzer', 0.225, 0.0),
#               ('LED (generic)', 0.2001, 1.0),
#               ('9V battery (generic)', 0.125, 0.0),
#               ('LDR 5 Mohm', 0.1002, 1.0),
#               ('Digilent IR Proximity Sensor', 0.1, 0.0),
#               ('USB-A to B Cable', 0.1, 0.0),
#               ('SparkFun Dual H-Bridge motor drivers L298', 0.05, 0.0)],
#              'hall effect': [('LED (generic)', 0.5005, 5.0),
#               ('Buzzer', 0.3002, 2.0),
#               ('Resistor 10k ohm', 0.2499, 2.0),
#               ('UTSOURCE Electronic Parts', 0.1739, 0.0),
#               ('DHT22 Temperature Sensor', 0.1256, 0.0),
#               ('9V battery (generic)', 0.1254, 0.0),
#               ('Solderless Breadboard Full Size', 0.1251, 1.0),
#               ('General Purpose Transistor NPN', 0.1248, 0.0),
#               ('Single Turn Potentiometer- 10k ohms', 0.1247, 2.0),
#               ('Solderless Breadboard Half Size', 0.0998, 0.0)],
#              'haptics': [('Arduino Nano R3', 0.475, 0.0),
#               ('Resistor 100 ohm', 0.175, 0.0),
#               ('Rotary potentiometer (generic)', 0.175, 0.0),
#               ('5 mm LED: Red', 0.15, 0.0),
#               ('Adafruit RGB Backlight LCD - 16x2', 0.125, 0.0),
#               ('SparkFun Pushbutton switch 12mm', 0.125, 0.0),
#               ('Custom PCB', 0.075, 0.0),
#               ('Particle Spark Core', 0.0501, 1.0),
#               ('Breadboard for wiring up', 0.05, 0.0),
#               ('4.7M Ohm resistor', 0.05, 0.0)],
#              'blinky lights': [('LED (generic)', 1.0001, 6.0),
#               ('Resistor 10k ohm', 0.8726, 1.0),
#               ('Relay (generic)', 0.201, 0.0),
#               ('1Sheeld', 0.1761, 0.0),
#               ('Espressif ESP8266 ESP-01', 0.15, 1.0),
#               ('Capacitor 10 F', 0.1247, 0.0),
#               ('5 mm LED: Green', 0.1241, 1.0),
#               ('Proximity Sensor', 0.1239, 0.0),
#               ('Adafruit NeoPixel Ring: WS2812 5050 RGB LED', 0.1005, 0.0),
#               ('Resistor 2.21k ohm', 0.0996, 0.0)],
#              '1284p': [('Arduino Nano R3', 0.2499, 0.0),
#               ('LED (generic)', 0.1499, 0.0),
#               ('Servos (Tower Pro MG996R)', 0.075, 0.0),
#               ('OpenBuilds NEMA 17 Stepper Motor', 0.05, 0.0),
#               ('USB-A to B Cable', 0.05, 0.0),
#               ('Temperature Sensor', 0.05, 0.0),
#               ('Resistor 100k ohm', 0.05, 0.0),
#               ('SparkFun Stepper motor driver board A4988', 0.05, 0.0),
#               ('SparkFun Pushbutton switch 12mm', 0.05, 0.0),
#               ('Adafruit Feather HUZZAH with ESP8266 WiFi', 0.025, 0.0)],
#              'cnc': [('Rotary potentiometer (generic)', 0.502, 0.0),
#               ('Resistor 221 ohm', 0.2995, 0.0),
#               ('Resistor 1k ohm', 0.1985, 0.0),
#               ('SparkFun Pushbutton switch 12mm', 0.1766, 0.0),
#               ('DHT11 Temperature & Humidity Sensor (4 pins)', 0.0764, 0.0),
#               ('uECG device', 0.0759, 0.0),
#               ('Servos (Tower Pro MG996R)', 0.0759, 3.0),
#               ('Capacitor 100 nF', 0.0752, 0.0),
#               ('Capacitor 10 F', 0.074, 0.0),
#               ('5 mm LED: Yellow', 0.0512, 0.0)],
#              'cascading': [('Ultrasonic Sensor - HC-SR04 (Generic)', 0.8, 0.0),
#               ('5 mm LED: Red', 0.6501, 1.0),
#               ('Jumper wires (generic)', 0.225, 1.0),
#               ('Espressif ESP8266 ESP-01', 0.05, 0.0),
#               ('Rotary potentiometer (generic)', 0.05, 0.0),
#               ('9V 1A Switching Wall Power Supply', 0.05, 0.0),
#               ('Resistor 1k ohm', 0.05, 0.0),
#               ('Servos (Tower Pro MG996R)', 0.05, 0.0),
#               ('1Sheeld', 0.025, 0.0),
#               ('SparkFun Ultrasonic Sensor - HC-SR04', 0.025, 0.0)],
#              'chickens': [('SparkFun Pushbutton switch 12mm', 0.1751, 0.0),
#               ('Resistor 330 ohm', 0.125, 0.0),
#               ('Solderless Breadboard Half Size', 0.1, 0.0),
#               ('HC-05 Bluetooth Module', 0.075, 0.0),
#               ('Linear Regulator (7805)', 0.0749, 0.0),
#               ('DC motor (generic)', 0.05, 0.0),
#               ('OpenBuilds NEMA 17 Stepper Motor', 0.05, 0.0),
#               ('DHT11 Temperature & Humidity Sensor (3 pins)', 0.05, 0.0),
#               ('L298n Motor Driver', 0.05, 0.0),
#               ('SparkFun Arduino Pro Mini 328 - 5V/16MHz', 0.05, 0.0)],
#              'twitter': [('Alphanumeric LCD 16 x 2', 0.1749, 0.0),
#               ('Relay (generic)', 0.1252, 0.0),
#               ('Photo resistor', 0.1251, 0.0),
#               ('SparkFun Ultrasonic Sensor - HC-SR04', 0.1001, 0.0),
#               ('SparkFun Pushbutton switch 12mm', 0.1001, 1.0),
#               ('Slide Switch', 0.0997, 0.0),
#               ('9V battery (generic)', 0.0753, 0.0),
#               ('Male/Female Jumper Wires', 0.0749, 0.0),
#               ('AA Batteries', 0.0748, 0.0),
#               ('9V 1A Switching Wall Power Supply', 0.0748, 1.0)],
#              'machine learning': [('Arduino Nano R3', 1.6216, 7.0),
#               ('Breadboard (generic)', 1.489, 6.0),
#               ('Resistor 10k ohm', 0.8681, 1.0),
#               ('Buzzer', 0.7969, 5.0),
#               ('Rotary potentiometer (generic)', 0.6908, 0.0),
#               ('Resistor 220 ohm', 0.5018, 1.0),
#               ('Resistor 1k ohm', 0.4682, 0.0),
#               ('9V battery (generic)', 0.2462, 4.0),
#               ('HC-05 Bluetooth Module', 0.1982, 1.0),
#               ('USB-A to B Cable', 0.1709, 1.0)],
#              'photo': [('Resistor 100 ohm', 0.2, 0.0),
#               ('Buzzer', 0.1749, 0.0),
#               ('5 mm LED: Green', 0.15, 0.0),
#               ('Power supply 12V 05A', 0.0751, 1.0),
#               ('USB-A to B Cable', 0.075, 0.0),
#               ('Alphanumeric LCD 16 x 2', 0.075, 0.0),
#               ('SparkFun Dual H-Bridge motor drivers L298', 0.05, 0.0),
#               ('Linear Regulator (7805)', 0.05, 0.0),
#               ('Espressif ESP8266 ESP-01', 0.05, 0.0),
#               ('Arduino Leonardo', 0.05, 0.0)],
#              'diorama': [('Breadboard (generic)', 0.3, 0.0),
#               ('Resistor 10k ohm', 0.275, 0.0),
#               ('Rotary potentiometer (generic)', 0.2, 0.0),
#               ('Arduino Mega 2560', 0.175, 0.0),
#               ('Resistor 100 ohm', 0.15, 0.0),
#               ('5 mm LED: Green', 0.125, 0.0),
#               ('resistors and capacitors', 0.075, 0.0),
#               ('1Sheeld', 0.05, 0.0),
#               ('Infrared Receiver Head Module LTM-8848-1 Liteon Semiconductors',
#                0.05,
#                0.0),
#               ('3 mm LED: Green', 0.05, 0.0)],
#              'brushless_motor': [('Jumper wires (generic)', 0.5249, 0.0),
#               ('Breadboard (generic)', 0.4499, 0.0),
#               ('Resistor 10k ohm', 0.175, 0.0),
#               ('LED (generic)', 0.1749, 0.0),
#               ('Resistor 1k ohm', 0.1499, 0.0),
#               ('Digilent IR Proximity Sensor', 0.075, 0.0),
#               ('OpenBuilds CNC xPRO V3 Controller Stepper Driver', 0.075, 0.0),
#               ('Android device', 0.075, 0.0),
#               ('Original New Touch Screen for Konica Minolta Bizhub C224 C284 C364 C554 C654 C754 control Panel',
#                0.075,
#                0.0),
#               ('Resistor 100k ohm', 0.05, 0.0)],
#              'mkr1000': [('Breadboard (generic)', 0.4001, 2.0),
#               ('Arduino Nano R3', 0.3747, 0.0),
#               ('Ultrasonic Sensor - HC-SR04 (Generic)', 0.3252, 2.0),
#               ('Arduino Due', 0.0749, 0.0),
#               ('SparkFun Solder-able Breadboard', 0.05, 0.0),
#               ('Digilent WS2812 Addressable LED Strip', 0.0499, 0.0),
#               ('Resistor 4.75k ohm', 0.0499, 0.0),
#               ('Maxim Integrated DS3231MPMB1 Peripheral Module', 0.0251, 0.0),
#               ('9V Battery Clip', 0.0251, 0.0),
#               ('Arduino MKR Fox 1200', 0.025, 0.0)],
#              'ecology': [('5 mm LED: Red', 0.1499, 0.0),
#               ('Solderless Breadboard Full Size', 0.1251, 0.0),
#               ('9V 1A Switching Wall Power Supply', 0.125, 0.0),
#               ('SG90 Micro-servo motor', 0.125, 1.0),
#               ('Arduino MKR1000', 0.0751, 0.0),
#               ('Photo resistor', 0.075, 0.0),
#               ('DC motor (generic)', 0.075, 0.0),
#               ('RGB Diffused Common Cathode', 0.075, 0.0),
#               ('Slide Switch', 0.0749, 0.0),
#               ('Espressif ESP8266 ESP-01', 0.05, 0.0)],
#              'garden': [('Arduino Nano R3', 3.3297, 11.0),
#               ('LED (generic)', 1.9597, 3.0),
#               ('Arduino Mega 2560', 1.5134, 5.0),
#               ('Rotary potentiometer (generic)', 0.9463, 6.0),
#               ('Resistor 330 ohm', 0.6454, 0.0),
#               ('SparkFun Soil Moisture Sensor (with Screw Terminals)',
#                0.5462,
#                5.0),
#               ('Adafruit RGB Backlight LCD - 16x2', 0.3756, 0.0),
#               ('RGB Diffused Common Cathode', 0.2513, 0.0),
#               ('Slide Switch', 0.2041, 0.0),
#               ('SparkFun Dual H-Bridge motor drivers L298', 0.202, 0.0)],
#              'arduino inclinometer mpu6050': [('5 mm LED: Red', 0.4255, 1.0),
#               ('9V battery (generic)', 0.3757, 1.0),
#               ('Arduino UNO', 0.3497, 0.0),
#               ('DFRobot 6 DOF Sensor - MPU6050', 0.2757, 1.0),
#               ('LED (generic)', 0.2247, 0.0),
#               ('Resistor 1k ohm', 0.0999, 0.0),
#               ('SparkFun Stepper motor driver board A4988', 0.0749, 0.0),
#               ('Pushbutton Switch Momentary', 0.0749, 0.0),
#               ('1N4007  High Voltage High Current Rated Diode', 0.0749, 0.0),
#               ('SparkFun Button Pad 4x4 - LED Compatible', 0.05, 0.0)],
#              'code': [('5 mm LED: Red', 0.4753, 1.0),
#               ('Arduino Nano R3', 0.1749, 0.0),
#               ('LED (generic)', 0.1749, 0.0),
#               ('Resistor 10k ohm', 0.1499, 0.0),
#               ('Alphanumeric LCD 16 x 2', 0.1249, 0.0),
#               ('Solderless Breadboard Full Size', 0.075, 0.0),
#               ('SparkFun Pushbutton switch 12mm', 0.075, 0.0),
#               ('SparkFun Dual H-Bridge motor drivers L298', 0.075, 0.0),
#               ('Male/Female Jumper Wires', 0.075, 0.0),
#               ('Espressif ESP8266 ESP-01', 0.05, 0.0)],
#              '6dof': [('Jumper wires (generic)', 0.3752, 2.0),
#               ('Arduino Nano R3', 0.35, 0.0),
#               ('Resistor 220 ohm', 0.2, 0.0),
#               ('5 mm LED: Red', 0.1752, 0.0),
#               ('LED (generic)', 0.1749, 0.0),
#               ('Solderless Breadboard Half Size', 0.0751, 0.0),
#               ('Ultrasonic Sensor - HC-SR04 (Generic)', 0.075, 0.0),
#               ('DC motor (generic)', 0.0501, 0.0),
#               ('Resistor 100k ohm', 0.05, 0.0),
#               ('High Brightness LED White', 0.0499, 0.0)],
#              'nuts and bolts': [('Arduino UNO', 0.975, 1.0),
#               ('Breadboard (generic)', 0.3251, 1.0),
#               ('Ultrasonic Sensor - HC-SR04 (Generic)', 0.3, 0.0),
#               ('Resistor 220 ohm', 0.225, 0.0),
#               ('Arduino Mega 2560', 0.15, 0.0),
#               ('Arduino Due', 0.075, 0.0),
#               ('DFRobot I2C 16x2 Arduino LCD Display Module', 0.05, 0.0),
#               ('Temperature Sensor', 0.05, 0.0),
#               ('Slide Switch', 0.05, 0.0),
#               ('Female/Female Jumper Wires', 0.05, 0.0)],
#              'clocks': [('Arduino UNO', 15.4805, 120.0),
#               ('Breadboard (generic)', 7.7202, 41.0),
#               ('9V battery (generic)', 1.2455, 6.0),
#               ('Arduino Micro', 1.2407, 3.0),
#               ('Resistor 220 ohm', 0.9779, 15.0),
#               ('SparkFun Arduino Pro Mini 328 - 5V/16MHz', 0.918, 5.0),
#               ('Raspberry Pi 3 Model B', 0.8173, 1.0),
#               ('General Purpose Transistor NPN', 0.7519, 9.0),
#               ('Resistor 100k ohm', 0.7345, 4.0),
#               ('DHT11 Temperature & Humidity Sensor (4 pins)', 0.7295, 6.0)],
#              'meterelogia': [('Arduino Nano R3', 0.2499, 0.0),
#               ('Original New Touch Screen for Konica Minolta Bizhub C224 C284 C364 C554 C654 C754 control Panel',
#                0.075,
#                0.0),
#               ('DHT11 Temperature & Humidity Sensor (3 pins)', 0.0501, 1.0),
#               ('Servos (Tower Pro MG996R)', 0.05, 0.0),
#               ('Battery Holder', 0.05, 0.0),
#               ('LED Light Bulb Frosted GLS', 0.05, 0.0),
#               ('MOSFET Transistor Switching', 0.025, 0.0),
#               ('Adafruit motor shield', 0.025, 0.0),
#               ('470 ohm resistor', 0.025, 0.0),
#               ('Resistor 1M ohm', 0.025, 0.0)],
#              'multifunctional robot': [('Arduino Nano R3', 0.35, 0.0),
#               ('Resistor 220 ohm', 0.175, 0.0),
#               ('Resistor 10k ohm', 0.175, 1.0),
#               ('5 mm LED: Red', 0.125, 0.0),
#               ('Rotary potentiometer (generic)', 0.125, 0.0),
#               ('Alphanumeric LCD 16 x 2', 0.1001, 0.0),
#               ('Solderless Breadboard Full Size', 0.1, 0.0),
#               ('9V Battery Clip', 0.1, 0.0),
#               ('Digilent IR Proximity Sensor', 0.0751, 0.0),
#               ("Itead Nextion NX8048T070 - Generic 7.0'' HMI TFT LCD Touch Display",
#                0.0501,
#                0.0)],
#              'indicator': [('Arduino UNO', 1.1, 1.0),
#               ('Breadboard (generic)', 0.6, 1.0),
#               ('Resistor 220 ohm', 0.3, 0.0),
#               ('5 mm LED: Red', 0.25, 1.0),
#               ('Alphanumeric LCD 16 x 2', 0.1, 0.0),
#               ('PIR Motion Sensor (generic)', 0.1, 0.0),
#               ('9V Battery Clip', 0.1, 0.0),
#               ('Resistor 100 ohm', 0.1, 0.0),
#               ('Hologram Global IoT SIM Card', 0.075, 0.0),
#               ('Resistor 330 ohm', 0.075, 0.0)],
#              'remote': [('Jumper wires (generic)', 0.4753, 3.0),
#               ('Breadboard (generic)', 0.4249, 3.0),
#               ('Adafruit Standard LCD - 16x2 White on Blue', 0.1501, 0.0),
#               ('Solderless Breadboard Full Size', 0.1251, 0.0),
#               ('Arduino Due', 0.1249, 0.0),
#               ('Buzzer', 0.1249, 0.0),
#               ('Ultrasonic Sensor - HC-SR04 (Generic)', 0.1, 0.0),
#               ('Relay Module (Generic)', 0.1, 0.0),
#               ('Resistor 100 ohm', 0.0751, 0.0),
#               ('Rotary Encoder with Push-Button', 0.0749, 0.0)],
#              'debouncing': [('Buzzer', 0.325, 0.0),
#               ('Adafruit Standard LCD - 16x2 White on Blue', 0.1751, 0.0),
#               ('Resistor 220 ohm', 0.175, 0.0),
#               ('Ultrasonic Sensor - HC-SR04 (Generic)', 0.1748, 0.0),
#               ('9V battery (generic)', 0.15, 0.0),
#               ('Resistor 100 ohm', 0.125, 1.0),
#               ('Resistor 1k ohm', 0.1249, 0.0),
#               ('Arduino Mega 2560', 0.075, 0.0),
#               ('Resistor 330 ohm', 0.075, 0.0),
#               ('Photo resistor', 0.075, 0.0)],
#              'lights': [('Arduino UNO', 41.0477, 172.0),
#               ('Arduino Mega 2560', 8.9003, 31.0),
#               ('LED (generic)', 7.7428, 65.0),
#               ('Resistor 221 ohm', 4.8013, 28.0),
#               ('HC-05 Bluetooth Module', 4.0557, 8.0),
#               ('DHT22 Temperature Sensor', 2.7234, 1.0),
#               ('DHT11 Temperature & Humidity Sensor (4 pins)', 2.5127, 3.0),
#               ('Arduino 101', 2.5057, 5.0),
#               ('Resistor 220 ohm', 2.2801, 18.0),
#               ('IR receiver (generic)', 1.7757, 2.0)],
#              'squirt': [('Ultrasonic Sensor - HC-SR04 (Generic)', 0.1749, 0.0),
#               ('SG90 Micro-servo motor', 0.1001, 0.0),
#               ('Servos (Tower Pro MG996R)', 0.1, 0.0),
#               ('SparkFun Arduino Pro Mini 328 - 5V/16MHz', 0.1, 0.0),
#               ('Slide Switch', 0.1, 0.0),
#               ('Adafruit Standard LCD - 16x2 White on Blue', 0.1, 0.0),
#               ('Arduino Mega 2560', 0.0999, 0.0),
#               ('Rotary potentiometer (generic)', 0.075, 0.0),
#               ('5 mm LED: Yellow', 0.075, 0.0),
#               ('IR receiver (generic)', 0.0501, 0.0)],
#              'legged': [('Arduino UNO', 0.8249, 0.0),
#               ('Breadboard (generic)', 0.5, 0.0),
#               ('Jumper wires (generic)', 0.4, 0.0),
#               ('Buzzer', 0.3999, 0.0),
#               ('5 mm LED: Red', 0.3749, 0.0),
#               ('Ultrasonic Sensor - HC-SR04 (Generic)', 0.3749, 0.0),
#               ('9V battery (generic)', 0.1499, 0.0),
#               ('Alphanumeric LCD 16 x 2', 0.1499, 0.0),
#               ('Raspberry Pi 3 Model B', 0.1252, 1.0),
#               ('General Purpose Transistor NPN', 0.125, 0.0)],
#              'costume': [('Arduino Nano R3', 0.4001, 2.0),
#               ('Breadboard (generic)', 0.3, 0.0),
#               ('LED (generic)', 0.225, 0.0),
#               ('Single Turn Potentiometer- 10k ohms', 0.1251, 0.0),
#               ('Alphanumeric LCD 16 x 2', 0.1, 0.0),
#               ('Arduino MKR WiFi 1010', 0.1, 0.0),
#               ('Female/Female Jumper Wires', 0.075, 0.0),
#               ('Push Button', 0.05, 0.0),
#               ('Arduino MKR 485 Shield', 0.05, 0.0),
#               ('4xAA battery holder', 0.05, 0.0)],
#              'servo': [('LED (generic)', 2.5166, 6.0),
#               ('Resistor 10k ohm', 2.1344, 9.0),
#               ('Resistor 1k ohm', 0.8954, 5.0),
#               ('Resistor 330 ohm', 0.8189, 1.0),
#               ('Slide Switch', 0.7787, 3.0),
#               ('SparkFun Arduino Pro Mini 328 - 5V/16MHz', 0.5108, 0.0),
#               ('Adafruit NeoPixel Ring: WS2812 5050 RGB LED', 0.4773, 0.0),
#               ('Texas Instruments Dual H-Bridge motor drivers L293D',
#                0.4643,
#                2.0),
#               ('Rotary Encoder with Push-Button', 0.4572, 0.0),
#               ('Linear Regulator (7805)', 0.3089, 0.0)],
#              'cayenne': [('SparkFun Pushbutton switch 12mm', 0.1751, 0.0),
#               ('Resistor 330 ohm', 0.1502, 1.0),
#               ('Ultrasonic Sensor - HC-SR04 (Generic)', 0.15, 0.0),
#               ('USB-A to B Cable', 0.1253, 0.0),
#               ('General Purpose Transistor NPN', 0.0501, 1.0),
#               ('Capacitor 100 nF', 0.05, 0.0),
#               ('DHT22 Temperature Sensor', 0.05, 1.0),
#               ('DHT11 Temperature & Humidity Sensor (4 pins)', 0.0499, 1.0),
#               ('Arduino Due', 0.0499, 0.0),
#               ('idIoTware Shield', 0.0251, 0.0)],
#              'launch': [('Jumper wires (generic)', 0.3499, 0.0),
#               ('Arduino Nano R3', 0.2499, 0.0),
#               ('Ultrasonic Sensor - HC-SR04 (Generic)', 0.175, 0.0),
#               ('1N4007  High Voltage High Current Rated Diode', 0.1, 0.0),
#               ('Alphanumeric LCD 16 x 2', 0.1, 0.0),
#               ('UTSOURCE Electronic Parts', 0.0751, 0.0),
#               ('Resistor 221 ohm', 0.075, 0.0),
#               ('Resistor 330 ohm', 0.075, 0.0),
#               ('BC547', 0.0501, 0.0),
#               ('Arduino Micro', 0.0501, 0.0)],
#              'resistors': [('Jumper wires (generic)', 0.6251, 2.0),
#               ('Resistor 10k ohm', 0.3501, 1.0),
#               ('LED (generic)', 0.2499, 0.0),
#               ('Resistor 1k ohm', 0.2, 1.0),
#               ('9V battery (generic)', 0.125, 0.0),
#               ('DHT11 Temperature & Humidity Sensor (3 pins)', 0.075, 0.0),
#               ('PIR Motion Sensor (generic)', 0.075, 0.0),
#               ('Arduino Due', 0.075, 0.0),
#               ('Darlington High Power Transistor', 0.05, 0.0),
#               ('General Purpose Transistor NPN', 0.05, 0.0)],
#              'fimo': [('Jumper wires (generic)', 0.3, 0.0),
#               ('LED (generic)', 0.1999, 0.0),
#               ('Espressif ESP8266 ESP-01', 0.125, 0.0),
#               ('9V battery (generic)', 0.1, 0.0),
#               ('Relay (generic)', 0.075, 0.0),
#               ('Cat Collar Bell', 0.0502, 1.0),
#               ('Raspberry Pi 2 Model B', 0.05, 0.0),
#               ('Pushbutton Switch Momentary', 0.05, 0.0),
#               ('Car door lock actuator', 0.05, 0.0),
#               ('Toggle Switch Toggle', 0.05, 0.0)],
#              'human machine interface': [('Arduino Nano R3', 0.325, 0.0),
#               ('Resistor 1k ohm', 0.2, 1.0),
#               ('HC-05 Bluetooth Module', 0.1001, 0.0),
#               ('Female/Female Jumper Wires', 0.1, 0.0),
#               ('Arduino MKR WiFi 1010', 0.075, 0.0),
#               ('USB-A to B Cable', 0.075, 0.0),
#               ('Solderless Breadboard Full Size', 0.075, 0.0),
#               ('BD139 Transistor', 0.05, 0.0),
#               ('Speaker: 0.25W 8 ohms', 0.05, 0.0),
#               ('Pushbutton Switch Momentary', 0.05, 0.0)],
#              'detection': [('Jumper wires (generic)', 0.7246, 4.0),
#               ('Arduino Mega 2560', 0.2747, 0.0),
#               ('Single Turn Potentiometer- 10k ohms', 0.1752, 0.0),
#               ('SparkFun Arduino Pro Mini 328 - 5V/16MHz', 0.1502, 0.0),
#               ('Alphanumeric LCD 16 x 2', 0.1251, 0.0),
#               ('Slide Switch', 0.1001, 0.0),
#               ('5 mm LED: Green', 0.0998, 1.0),
#               ('22 gauge tinned copper wire', 0.0503, 0.0),
#               ('16 MHz Crystal', 0.0502, 0.0),
#               ('Arduino Due', 0.0501, 0.0)],
#              'xbox': [('Resistor 220 ohm', 0.2999, 0.0),
#               ('Buzzer', 0.275, 0.0),
#               ('SparkFun Dual H-Bridge motor drivers L298', 0.1, 0.0),
#               ('Servos (Tower Pro MG996R)', 0.1, 0.0),
#               ('Analog joystick (Generic)', 0.05, 0.0),
#               ('USB-A to B Cable', 0.05, 0.0),
#               ('Adafruit motorshield V1', 0.05, 0.0),
#               ('PIR Motion Sensor (generic)', 0.05, 0.0),
#               ('Male/Female Jumper Wires', 0.05, 0.0),
#               ('Micro USB Cable', 0.025, 0.0)],
#              'mit app inventor bluetooth arduino': [('Male/Female Jumper Wires',
#                0.2757,
#                1.0),
#               ('LED (generic)', 0.2748, 0.0),
#               ('Resistor 330 ohm', 0.2499, 0.0),
#               ('Fan Accessory AC Motor', 0.2256, 1.0),
#               ('Resistor 10k ohm', 0.2249, 0.0),
#               ('Digilent 5V 2.5A Switching Power Supply', 0.2006, 1.0),
#               ('Alphanumeric LCD 16 x 2', 0.1, 0.0),
#               ('Adafruit Standard LCD - 16x2 White on Blue', 0.0999, 0.0),
#               ('Ultrasonic Sensor - HC-SR04 (Generic)', 0.075, 0.0),
#               ('HC-06 Bluetooth Module', 0.0749, 0.0)],
#              'sd card': [('LED (generic)', 0.2502, 1.0),
#               ('Resistor 221 ohm', 0.175, 0.0),
#               ('Resistor 220 ohm', 0.1498, 0.0),
#               ('USB-A to B Cable', 0.1002, 0.0),
#               ('Tactile Switch Top Actuated', 0.0999, 0.0),
#               ('Rotary potentiometer (generic)', 0.0997, 0.0),
#               ('Espressif Wemos D1 Mini', 0.0752, 1.0),
#               ('Arduino MKR1000', 0.0501, 0.0),
#               ('OpenBuilds Wire Cable - By the Foot', 0.0501, 0.0),
#               ('NeuroSky MindWave', 0.0501, 0.0)],
#              'transcoder': [('DC motor (generic)', 0.15, 0.0),
#               ('Resistor 330 ohm', 0.1251, 1.0),
#               ('Rotary potentiometer (generic)', 0.125, 0.0),
#               ('Resistor 1k ohm', 0.1, 0.0),
#               ('Arduino Micro', 0.075, 0.0),
#               ('Resistor 100 ohm', 0.075, 0.0),
#               ('9V battery (generic)', 0.075, 0.0),
#               ('WIZnet WIZwiki-W7500', 0.075, 0.0),
#               ('Seeed Studio Grove - Gas Sensor(MQ2)', 0.05, 0.0),
#               ('OpenBuilds NEMA 17 Stepper Motor', 0.05, 0.0)],
#              'windows remote arduino': [('Breadboard (generic)', 0.575, 0.0),
#               ('Resistor 330 ohm', 0.15, 0.0),
#               ('Resistor 220 ohm', 0.15, 0.0),
#               ('HC-05 Bluetooth Module', 0.0751, 0.0),
#               ('Toggle Switch Toggle', 0.075, 0.0),
#               ('Gear motor', 0.0501, 0.0),
#               ('Photo resistor', 0.05, 0.0),
#               ('Pushbutton Switch Push-Pull', 0.05, 0.0),
#               ('Relay Module (Generic)', 0.05, 0.0),
#               ('Servos (Tower Pro MG996R)', 0.05, 0.0)],
#              'color sensor': [('5 mm LED: Red', 0.0749, 0.0),
#               ('Male/Male Jumper Wires', 0.05, 0.0),
#               ('WIZnet WIZ750SR-TTL-EVB Kit', 0.05, 0.0),
#               ('DC motor (generic)', 0.05, 0.0),
#               ('Linear Regulator (7805)', 0.05, 0.0),
#               ('General Purpose Transistor NPN', 0.05, 0.0),
#               ('Arduino Yun', 0.05, 0.0),
#               ('Capacitor 100 nF', 0.05, 0.0),
#               ('LDR 5 Mohm', 0.0499, 0.0),
#               ('push buttons', 0.0251, 0.0)],
#              'smartwatches': [('Arduino UNO', 1.2753, 4.0),
#               ('HC-05 Bluetooth Module', 0.2499, 2.0),
#               ('Arduino Mega 2560', 0.1502, 0.0),
#               ('Ultrasonic Sensor - HC-SR04 (Generic)', 0.1498, 0.0),
#               ('Thermistor', 0.1253, 0.0),
#               ('Resistor 100 ohm', 0.125, 0.0),
#               ('9V battery (generic)', 0.1001, 0.0),
#               ('Solderless Breadboard Full Size', 0.0998, 0.0),
#               ('Tactile Switch Top Actuated', 0.0751, 0.0),
#               ('DHT11 Temperature & Humidity Sensor (3 pins)', 0.0751, 0.0)],
#              'lora projects': [('Resistor 10k ohm', 0.3749, 0.0),
#               ('5 mm LED: Red', 0.2, 1.0),
#               ('Rotary potentiometer (generic)', 0.1749, 0.0),
#               ('5 mm LED: Yellow', 0.1, 0.0),
#               ('Arduino MKR1000', 0.075, 0.0),
#               ('Alphanumeric LCD 16 x 2', 0.0749, 0.0),
#               ('BH1750FVI Digital Light Intensity Sensor Module', 0.05, 0.0),
#               ('SparkFun Arduino Pro Mini 328 - 5V/16MHz', 0.05, 0.0),
#               ('4xAA battery holder', 0.05, 0.0),
#               ('Original New Touch Screen for Konica Minolta Bizhub C224 C284 C364 C554 C654 C754 control Panel',
#                0.05,
#                0.0)],
#              'gauge': [('Resistor 10k ohm', 0.3751, 0.0),
#               ('Jumper wires (generic)', 0.2749, 0.0),
#               ('Breadboard (generic)', 0.225, 0.0),
#               ('Arduino Mega 2560', 0.15, 0.0),
#               ('Slide Switch', 0.1249, 0.0),
#               ('5 mm LED: Red', 0.1, 0.0),
#               ('Single Turn Potentiometer- 10k ohms', 0.1, 1.0),
#               ('Resistor 221 ohm', 0.0751, 0.0),
#               ('1N4148  General Purpose Fast Switching', 0.0751, 0.0),
#               ('DC motor (generic)', 0.075, 0.0)],
#              'fishing': [('Arduino UNO', 0.9251, 1.0),
#               ('Breadboard (generic)', 0.3999, 0.0),
#               ('Alphanumeric LCD 16 x 2', 0.1499, 0.0),
#               ('LED (generic)', 0.125, 0.0),
#               ('5 mm LED: Red', 0.075, 0.0),
#               ('SG90 Micro-servo motor', 0.075, 0.0),
#               ('Infrared Receiver Remote Control', 0.05, 0.0),
#               ('9V 1A Switching Wall Power Supply', 0.05, 0.0),
#               ('Arduino 101', 0.05, 0.0),
#               ('PIR Motion Sensor (generic)', 0.05, 0.0)],
#              'iron': [('Arduino UNO', 0.6749, 0.0),
#               ('Arduino Nano R3', 0.55, 1.0),
#               ('HC-05 Bluetooth Module', 0.325, 0.0),
#               ('LED Light Bulb Frosted GLS', 0.3, 0.0),
#               ('Female/Female Jumper Wires', 0.2001, 0.0),
#               ('Fan Accessory AC Motor', 0.2001, 0.0),
#               ('Solderless Breadboard Full Size', 0.175, 0.0),
#               ('Resistor 10k ohm', 0.1749, 0.0),
#               ('Seeed Studio Grove - Touch Sensor SKU 101020037', 0.1501, 0.0),
#               ('Relay Module (Generic)', 0.1501, 0.0)],
#              'co2': [('Resistor 220 ohm', 0.4001, 0.0),
#               ('Ultrasonic Sensor - HC-SR04 (Generic)', 0.35, 0.0),
#               ('5 mm LED: Red', 0.3001, 0.0),
#               ('Arduino Nano R3', 0.275, 0.0),
#               ('LED (generic)', 0.2, 0.0),
#               ('HC-05 Bluetooth Module', 0.1249, 0.0),
#               ('Rotary potentiometer (generic)', 0.1001, 0.0),
#               ('SparkFun Pushbutton switch 12mm', 0.1, 0.0),
#               ('9V 1A Switching Wall Power Supply', 0.0749, 0.0),
#               ('Flash Memory Card MicroSD Card', 0.05, 0.0)],
#              'l298 stepper motor driver schematic': [('Rotary Encoder with Push-Button',
#                0.1755,
#                1.0),
#               ('Arduino Micro', 0.1499, 0.0),
#               ('Adafruit RGB Backlight LCD - 16x2', 0.1249, 0.0),
#               ('SparkFun Pushbutton switch 12mm', 0.1249, 0.0),
#               ('9V battery (generic)', 0.1249, 0.0),
#               ('LED Light Bulb Frosted GLS', 0.1, 0.0),
#               ('SparkFun Stepper motor driver board A4988', 0.1, 0.0),
#               ('Resistor 100 ohm', 0.0999, 0.0),
#               ('Digilent IR Proximity Sensor', 0.075, 0.0),
#               ('Resistor 330 ohm', 0.05, 0.0)],
#              'i7sanmachine': [('Arduino UNO', 1.0999, 1.0),
# ...
#               ('Male/Female Jumper Wires', 0.5483, 6.0),
#               ('Arduino 101', 0.5182, 8.0),
#               ('5 mm LED: Green', 0.5169, 0.0),
#               ('Adafruit RGB Backlight LCD - 16x2', 0.3725, 1.0)],
#              'electronic': [('Breadboard (generic)', 0.5752, 1.0),
#               ('Jumper wires (generic)', 0.5002, 1.0),
#               ('Resistor 10k ohm', 0.2, 0.0),
#               ('9V 1A Switching Wall Power Supply', 0.075, 0.0),
#               ('Tactile Switch Top Actuated', 0.075, 0.0),
#               ('Single Turn Potentiometer- 10k ohms', 0.05, 0.0),
#               ('Photo resistor', 0.05, 0.0),
#               ('Water Pump', 0.0251, 0.0),
#               ('Perfboard', 0.0251, 0.0),
#               ('TimeDock', 0.0251, 0.0)],
#              'attiny85': [('HC-05 Bluetooth Module', 0.1999, 0.0),
#               ('5 mm LED: Red', 0.1499, 0.0),
#               ('Resistor 10k ohm', 0.1, 0.0),
#               ('Single Turn Potentiometer- 10k ohms', 0.1, 0.0),
#               ('SparkFun Dual H-Bridge motor drivers L298', 0.1, 0.0),
#               ('1Sheeld', 0.0751, 0.0),
#               ('Rotary potentiometer (generic)', 0.075, 0.0),
#               ('General Purpose Transistor NPN', 0.05, 0.0),
#               ('IR receiver (generic)', 0.05, 0.0),
#               ('OpenBuilds NEMA 17 Stepper Motor', 0.05, 0.0)],
#              'electronicsprojects': [('Arduino UNO', 1.025, 1.0),
#               ('Breadboard (generic)', 1.0, 1.0),
#               ('Ultrasonic Sensor - HC-SR04 (Generic)', 0.975, 1.0),
#               ('Buzzer', 0.95, 1.0),
#               ('Arduino Nano R3', 0.1, 0.0),
#               ('SparkFun Solder-able Breadboard', 0.075, 0.0),
#               ('5 mm LED: Green', 0.05, 0.0),
#               ('Enclosure', 0.05, 0.0),
#               ('BH1750FVI Digital Light Intensity Sensor Module', 0.025, 0.0),
#               ('7 Segment LED Display InfoVue', 0.025, 0.0)],
#              'encoder': [('Resistor 1k ohm', 0.2, 0.0),
#               ('9V battery (generic)', 0.1994, 1.0),
#               ('SparkFun Pushbutton switch 12mm', 0.199, 0.0),
#               ('Ultrasonic Sensor - HC-SR04 (Generic)', 0.1749, 0.0),
#               ('Arduino Mega 2560', 0.1255, 1.0),
#               ('Resistor 100 ohm', 0.1249, 0.0),
#               ('Servos (Tower Pro MG996R)', 0.1003, 0.0),
#               ('Relay Module (Generic)', 0.0751, 0.0),
#               ('5 mm LED: Green', 0.0747, 0.0),
#               ('Arduino Due', 0.0746, 0.0)],
#              'escornabot': [('Arduino UNO', 0.5749, 0.0),
#               ('Breadboard (generic)', 0.425, 0.0),
#               ('SparkFun Pushbutton switch 12mm', 0.25, 0.0),
#               ('Resistor 100k ohm', 0.15, 0.0),
#               ('Adafruit Standard LCD - 16x2 White on Blue', 0.15, 0.0),
#               ('Rotary potentiometer (generic)', 0.125, 0.0),
#               ('9V Battery Clip', 0.1, 0.0),
#               ('Resistor 330 ohm', 0.1, 0.0),
#               ('HC-06 Bluetooth Module', 0.0751, 1.0),
#               ('Arduino Proto Shield', 0.075, 0.0)],
#              'office': [('Arduino Nano R3', 0.6746, 4.0),
#               ('Resistor 330 ohm', 0.1498, 0.0),
#               ('SG90 Micro-servo motor', 0.1252, 0.0),
#               ('Resistor 1k ohm', 0.1246, 1.0),
#               ('Alphanumeric LCD 16 x 2', 0.1002, 0.0),
#               ('Android device', 0.0998, 0.0),
#               ('Servos (Tower Pro MG996R)', 0.0756, 0.0),
#               ('Resistor 220 ohm', 0.0752, 0.0),
#               ('Hall Effect Sensor', 0.0751, 0.0),
#               ('Resistor 100 ohm', 0.0749, 0.0)],
#              'coffee': [('Arduino Nano R3', 0.4249, 2.0),
#               ('9V battery (generic)', 0.2499, 0.0),
#               ('LED (generic)', 0.2499, 1.0),
#               ('Arduino Mega 2560', 0.175, 0.0),
#               ('Resistor 10k ohm', 0.125, 0.0),
#               ('Servos (Tower Pro MG996R)', 0.1001, 0.0),
#               ('1Sheeld', 0.1, 0.0),
#               ('Resistor 330 ohm', 0.1, 0.0),
#               ('Alphanumeric LCD 16 x 2', 0.0999, 0.0),
#               ('HC-05 Bluetooth Module', 0.075, 0.0)],
#              'sparkfun': [('Breadboard (generic)', 0.4251, 1.0),
#               ('Ultrasonic Sensor - HC-SR04 (Generic)', 0.375, 0.0),
#               ('Buzzer', 0.35, 0.0),
#               ('Arduino Nano R3', 0.225, 1.0),
#               ('Resistor 10k ohm', 0.125, 0.0),
#               ('Arduino Mega 2560', 0.1, 0.0),
#               ('Capacitor 1000 F', 0.075, 0.0),
#               ('Wires', 0.075, 0.0),
#               ('Resistor 4.75k ohm', 0.075, 0.0),
#               ('Digilent IR Proximity Sensor', 0.075, 0.0)],
#              'cube': [('Arduino UNO', 0.875, 1.0),
#               ('Arduino Nano R3', 0.525, 2.0),
#               ('Jumper wires (generic)', 0.475, 1.0),
#               ('Breadboard (generic)', 0.425, 0.0),
#               ('9V battery (generic)', 0.15, 0.0),
#               ('Resistor 330 ohm', 0.125, 1.0),
#               ('Alphanumeric LCD 16 x 2', 0.125, 0.0),
#               ('USB-A to B Cable', 0.1, 0.0),
#               ('Arduino Yun', 0.05, 0.0),
#               ('Rotary Encoder with Push-Button', 0.05, 0.0)],
#              'aquaponics': [('Arduino Nano R3', 0.4, 1.0),
#               ('Resistor 10k ohm', 0.1748, 0.0),
#               ('HC-05 Bluetooth Module', 0.1502, 0.0),
#               ('Resistor 1k ohm', 0.1249, 0.0),
#               ('Solderless Breadboard Full Size', 0.0752, 0.0),
#               ('SG90 Micro-servo motor', 0.075, 0.0),
#               ('9V battery (generic)', 0.075, 0.0),
#               ('Adafruit Standard LCD - 16x2 White on Blue', 0.0501, 0.0),
#               ('Resistor 4.75k ohm', 0.05, 1.0),
#               ('Buttons', 0.0499, 0.0)],
#              'throttle': [('Buzzer', 0.2749, 0.0),
#               ('Resistor 220 ohm', 0.2749, 0.0),
#               ('Servos (Tower Pro MG996R)', 0.1001, 1.0),
#               ('General Purpose Transistor NPN', 0.1, 0.0),
#               ('Breadboard for wiring up', 0.05, 0.0),
#               ('4.7M Ohm resistor', 0.05, 0.0),
#               ('Slide Switch', 0.05, 0.0),
#               ('Arduino Due', 0.05, 0.0),
#               ('Development Kit Accessory Jumper Wire Kit', 0.025, 0.0),
#               ('Fan Accessory AC Motor', 0.025, 0.0)],
#              'robot': [('Jumper wires (generic)', 5.0744, 36.0),
#               ('Breadboard (generic)', 2.1988, 18.0),
#               ('Buzzer', 1.4093, 7.0),
#               ('Adafruit Standard LCD - 16x2 White on Blue', 1.2762, 0.0),
#               ('9V battery (generic)', 0.7779, 16.0),
#               ('Rotary potentiometer (generic)', 0.6108, 5.0),
#               ('Raspberry Pi 3 Model B', 0.485, 4.0),
#               ('General Purpose Transistor NPN', 0.3961, 2.0),
#               ('Adafruit NeoPixel Ring: WS2812 5050 RGB LED', 0.3576, 0.0),
#               ('Resistor 220 ohm', 0.3141, 1.0)],
#              'touch panel': [('Arduino Nano R3', 0.15, 0.0),
#               ('Resistor 221 ohm', 0.125, 0.0),
#               ('Adafruit Standard LCD - 16x2 White on Blue', 0.125, 0.0),
#               ('Solderless Breadboard Full Size', 0.1249, 0.0),
#               ('9V Battery Clip', 0.075, 0.0),
#               ('Linear Regulator (7805)', 0.075, 0.0),
#               ('DIN Audio / Video Connector 5 Contacts', 0.05, 0.0),
#               ('Relay Module (Generic)', 0.05, 0.0),
#               ('SparkFun Arduino Pro Mini 328 - 5V/16MHz', 0.05, 0.0),
#               ('SparkFun Solder-able Breadboard', 0.05, 0.0)],
#              'iphone': [('Arduino UNO', 1.0004, 6.0),
#               ('Arduino Nano R3', 0.3001, 0.0),
#               ('SG90 Micro-servo motor', 0.2504, 1.0),
#               ('Tamiya Universal Plate 70098', 0.1754, 1.0),
#               ('Tamiya Track and Wheel Set 70100', 0.1754, 1.0),
#               ('Resistor 220 ohm', 0.1499, 0.0),
#               ('Tamiya Gearbox 70168', 0.1002, 1.0),
#               ('Male/Female Jumper Wires', 0.075, 0.0),
#               ('Resistor 1k ohm', 0.075, 0.0),
#               ('Tactile Switch Top Actuated', 0.05, 0.0)],
#              'l298n': [('Breadboard (generic)', 0.5249, 0.0),
#               ('Resistor 220 ohm', 0.2499, 0.0),
#               ('Resistor 1k ohm', 0.1501, 1.0),
#               ('Alphanumeric LCD 16 x 2', 0.125, 0.0),
#               ('DC Motor 12 V', 0.1002, 1.0),
#               ('Resistor 221 ohm', 0.0751, 1.0),
#               ('Single Turn Potentiometer- 10k ohms', 0.0749, 0.0),
#               ('Espressif ESP8266 ESP-01', 0.0749, 0.0),
#               ('Slide Switch', 0.0501, 0.0),
#               ('Resistor 150 ohm', 0.05, 0.0)],
#              'sms': [('Arduino UNO', 1.4729, 10.0),
#               ('Jumper wires (generic)', 0.6995, 10.0),
#               ('Arduino Nano R3', 0.4995, 0.0),
#               ('Arduino Mega 2560', 0.3498, 3.0),
#               ('Male/Female Jumper Wires', 0.1499, 0.0),
#               ('Resistor 1k ohm', 0.125, 0.0),
#               ('Resistor 330 ohm', 0.1, 0.0),
#               ('Resistor 4.75k ohm', 0.0751, 0.0),
#               ('Adafruit RGB Backlight LCD - 16x2', 0.0749, 0.0),
#               ('Single Turn Potentiometer- 10k ohms', 0.0749, 0.0)],
#              'reprap': [('Proximity sensor', 0.176, 1.0),
#               ('Aluminum Sheets', 0.176, 1.0),
#               ('LED Light', 0.176, 1.0),
#               ('Heatbed', 0.176, 1.0),
#               ('600 watt power supply', 0.1258, 1.0),
#               ('Cooling Fans', 0.1005, 1.0),
#               ('Arduino Micro', 0.075, 0.0),
#               ('Raspberry Pi 3 Model B', 0.0749, 0.0),
#               ('Arduino Yun', 0.0749, 0.0),
#               ('Capacitor 10 F', 0.0749, 0.0)],
#              'cut the cord': [('Arduino UNO', 0.9001, 1.0),
#               ('Jumper wires (generic)', 0.4751, 0.0),
#               ('Breadboard (generic)', 0.35, 0.0),
#               ('Arduino Nano R3', 0.225, 0.0),
#               ('Arduino Micro', 0.15, 0.0),
#               ('Adafruit RGB Backlight LCD - 16x2', 0.125, 0.0),
#               ('Rotary potentiometer (generic)', 0.125, 0.0),
#               ('Relay Module (Generic)', 0.075, 0.0),
#               ('Wires', 0.075, 0.0),
#               ('5 mm LED: Green', 0.075, 0.0)],
#              'transistortester': [('Resistor 1k ohm', 0.2249, 1.0),
#               ('Alphanumeric LCD 16 x 2', 0.1999, 0.0),
#               ('Resistor 100 ohm', 0.125, 0.0),
#               ('9V battery (generic)', 0.125, 0.0),
#               ('Rotary potentiometer (generic)', 0.1249, 0.0),
#               ('Arduino Ethernet Rev. 3', 0.075, 0.0),
#               ('LED Light Bulb Frosted GLS', 0.075, 0.0),
#               ('USB-A to B Cable', 0.075, 0.0),
#               ('SparkFun Arduino Pro Mini 328 - 5V/16MHz', 0.0749, 0.0),
#               ('DHT11 Temperature & Humidity Sensor (3 pins)', 0.05, 0.0)],
#              'decoration': [('Resistor 220 ohm', 0.1503, 1.0),
#               ('LED (generic)', 0.1498, 0.0),
#               ('Rotary potentiometer (generic)', 0.0999, 0.0),
#               ('3 mm LED: Green', 0.0756, 1.0),
#               ('HC-05 Bluetooth Module', 0.075, 0.0),
#               ('Slide Switch', 0.075, 0.0),
#               ('Single Turn Potentiometer- 10k ohms', 0.075, 0.0),
#               ('SparkFun Solder-able Breadboard', 0.0503, 2.0),
#               ('20 gauge tinned bare wire 30 feet', 0.0503, 1.0),
#               ("1/2'' plywood 2", 0.0503, 1.0)],
#              'heart rate': [('Arduino UNO', 1.05, 5.0),
#               ('Arduino Nano R3', 0.4751, 6.0),
#               ('Buzzer', 0.2751, 1.0),
#               ('5 mm LED: Red', 0.1502, 1.0),
#               ('Alphanumeric LCD 16 x 2', 0.125, 0.0),
#               ('Solderless Breadboard Full Size', 0.1001, 0.0),
#               ('Texas Instruments Shift Register- Serial to Parallel',
#                0.0751,
#                0.0),
#               ('Capacitor 100 F', 0.0749, 1.0),
#               ('USB-A to Mini-USB Cable', 0.0748, 0.0),
#               ('IDT Qi 5W Receiver Prototype Kit', 0.0501, 0.0)],
#              'arduino display': [('Breadboard (generic)', 0.975, 1.0),
#               ('5 mm LED: Red', 0.9251, 1.0),
#               ('Buzzer', 0.9251, 1.0),
#               ('Jumper wires (generic)', 0.0749, 0.0),
#               ('RGB Diffused Common Cathode', 0.05, 0.0),
#               ('Servos (Tower Pro MG996R)', 0.025, 0.0),
#               ('Resistor 330 ohm', 0.025, 0.0),
#               ('Arduino Proto Shield', 0.025, 0.0),
#               ('SparkFun LilyPad Coin Cell Battery Holder - Switched - 20mm',
#                0.025,
#                0.0),
#               ('Servo MG995', 0, 0.0)],
#              'usb midi synthisizer': [('Breadboard (generic)', 0.2999, 0.0),
#               ('LED (generic)', 0.2499, 0.0),
#               ('Arduino Mega 2560', 0.1749, 0.0),
#               ('Resistor 330 ohm', 0.1499, 0.0),
#               ('3 mm LED: Red', 0.0754, 1.0),
#               ('resistors and capacitors', 0.05, 0.0),
#               ('Alphanumeric LCD 16 x 2', 0.05, 0.0),
#               ('Slide Switch', 0.05, 0.0),
#               ('Screws', 0.05, 0.0),
#               ('Temperature Sensor', 0.05, 0.0)],
#              'arduino 101': [('Alphanumeric LCD 16 x 2', 0.175, 0.0),
#               ('5 mm LED: Red', 0.0999, 0.0),
#               ('General Purpose Transistor NPN', 0.0751, 0.0),
#               ('LED Light Bulb Frosted GLS', 0.075, 0.0),
#               ('Capacitor 100 F', 0.0501, 0.0),
#               ('LED Strip 5 m', 0.05, 0.0),
#               ('Arduino Leonardo', 0.05, 0.0),
#               ('Hook Up Wire Kit 22 AWG', 0.05, 0.0),
#               ('1Sheeld', 0.025, 0.0),
#               ('Philips hue', 0.025, 0.0)],
#              'cycling': [('Jumper wires (generic)', 0.7254, 5.0),
#               ('Breadboard (generic)', 0.5499, 4.0),
#               ('LED (generic)', 0.3502, 2.0),
#               ('Buzzer', 0.2244, 1.0),
#               ('Resistor 221 ohm', 0.1747, 0.0),
#               ('SG90 Micro-servo motor', 0.1502, 0.0),
#               ('HC-05 Bluetooth Module', 0.15, 1.0),
#               ('Arduino Micro', 0.1249, 0.0),
#               ('Hall Effect Sensor', 0.1001, 2.0),
#               ('Espressif ESP8266 ESP-01', 0.1001, 0.0)],
#              'electric shades': [('Jumper wires (generic)', 0.65, 1.0),
#               ('Breadboard (generic)', 0.4, 0.0),
#               ('Arduino Nano R3', 0.3, 0.0),
#               ('Resistor 1k ohm', 0.25, 0.0),
#               ('Male/Female Jumper Wires', 0.125, 0.0),
#               ('Alphanumeric LCD 16 x 2', 0.125, 0.0),
#               ('Female/Female Jumper Wires', 0.125, 0.0),
#               ('Arduino Micro', 0.1, 0.0),
#               ('fuse holder', 0.0752, 1.0),
#               ('BD139 Transistor', 0.05, 0.0)],
#              'led drivers': [('Arduino UNO', 0.925, 0.0),
#               ('Breadboard (generic)', 0.3999, 0.0),
#               ('Resistor 10k ohm', 0.3251, 1.0),
#               ('SparkFun Pushbutton switch 12mm', 0.3001, 0.0),
#               ('Buzzer', 0.3, 0.0),
#               ('9V battery (generic)', 0.225, 0.0),
#               ('Arduino Nano R3', 0.175, 1.0),
#               ('Adafruit Standard LCD - 16x2 White on Blue', 0.125, 0.0),
#               ('LDR 5 Mohm', 0.075, 0.0),
#               ('HC-05 Bluetooth Module', 0.075, 0.0)],
#              'food and drinks': [('Arduino Nano R3', 1.7003, 12.0),
#               ('Ultrasonic Sensor - HC-SR04 (Generic)', 0.7231, 1.0),
#               ('Arduino MKR1000', 0.4486, 4.0),
#               ('5 mm LED: Red', 0.4281, 2.0),
#               ('Resistor 330 ohm', 0.4275, 2.0),
#               ('5 mm LED: Green', 0.3511, 2.0),
#               ('Real Time Clock (RTC)', 0.254, 0.0),
#               ('SparkFun Arduino Pro Mini 328 - 5V/16MHz', 0.2509, 0.0),
#               ('RGB Diffused Common Cathode', 0.2004, 0.0),
#               ('Capacitor 10 F', 0.1751, 0.0)],
#              'science': [('Breadboard (generic)', 0.4502, 4.0),
#               ('Resistor 220 ohm', 0.2502, 1.0),
#               ('Resistor 330 ohm', 0.1, 0.0),
#               ('Maxim Integrated DS3231MPMB1 Peripheral Module', 0.0751, 0.0),
#               ('Resistor 1k ohm', 0.0749, 0.0),
#               ('MQ9 Gas sensor', 0.0501, 0.0),
#               ('9V Battery Clip', 0.0501, 0.0),
#               ('MQ135 Gas sensor', 0.0501, 0.0),
#               ('Photo resistor', 0.05, 0.0),
#               ('Espressif ESP8266 ESP-01', 0.05, 0.0)],
#              ...})

# %%
from collections import defaultdict

def get_top_n2( predictions, n=10):
    """Return the top-N recommendation for each user from a set of predictions.

    Args:
        predictions(list of Prediction objects): The list of predictions, as
            returned by the test method of an algorithm.
        n(int): The number of recommendation to output for each user. Default
            is 10.

    Returns:
    A dict where keys are user (raw) ids and values are lists of tuples:
        [(raw item id, rating estimation), ...] of size n.
    """

    # First map the predictions to each user.
    
    top_n = defaultdict(list)
    for  uid,iid, true_r, est, _ in predictions:
        top_n[uid].append((iid, float(round(est,6)),float(true_r)))

    # Then sort the predictions for each user and retrieve the k highest ones.
    for iid, user_ratings in top_n.items():
        user_ratings.sort(key=lambda x: x[1], reverse=True)
        top_n[iid] = user_ratings[:n]

    return top_n

# %%
type(top_n_recommendations['challenge'][0][1])
# Out:
# numpy.float64

# %%
top_n_recommendations=get_top_n2(predictions=tag_comp_predictions,n=10)

# %%
type(top_n_recommendations['challenge'][0][1])
# Out:
# float

# %%
file='recommendation.json'
jsonfile=json.dumps(dict(top_n_recommendations))
type(jsonfile)
with open(file, 'w') as convert_file:
    convert_file.write(jsonfile)

# %%
"""

Write Top n Recommendation to File for Tag Component

"""

recommender.write_recommendation_to_file(top_n_recommendations = {}, file = 'C:\\progetti\\low-code-ard-proj\\resyduo_components\\recommender_component\\recommendation_storage\\top10_rec_surprise_tag_comp_cut_5_5.json')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17948\2222251591.py in <module>
#       5 """
#       6
# ----> 7 recommender.write_recommendation_to_file(top_n_recommendations = {}, file = 'C:\\progetti\\low-code-ard-proj\\resyduo_components\\recommender_component\\recommendation_storage\\top10_rec_surprise_tag_comp_cut_5_5.json')
#
# TypeError: write_recommendation_to_file() got multiple values for argument 'top_n_recommendations'
